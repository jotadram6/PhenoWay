# %%
from AnasWorld import *

# %% [markdown]
# # Muon Channel

# %%
Z1_M500_df = pd.read_csv("../Wprime_VBF_gWWpZ1_M500.csv")
Z1_M1000_df = pd.read_csv("../Wprime_VBF_gWWpZ1.csv")
Z1_M3000_df = pd.read_csv("../Wprime_VBF_gWWpZ1_M3000.csv")

Z2_M500_df = pd.read_csv("../Wprime_VBF_gWWpZ2_M500.csv")
Z2_M1000_df = pd.read_csv("../Wprime_VBF_gWWpZ2.csv")
Z2_M3000_df = pd.read_csv("../Wprime_VBF_gWWpZ2_M3000.csv")

# %%
Z1_M500_df_mu = basic_allch_cuts(Z1_M500_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 0, n_mu = 1, pt_mu = 25)
Z1_M1000_df_mu = basic_allch_cuts(Z1_M1000_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 0, n_mu = 1, pt_mu = 25)
Z1_M3000_df_mu = basic_allch_cuts(Z1_M3000_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 0, n_mu = 1, pt_mu = 25)

m_T_Z1_M500, m_jj_Z1_M500, Delta_eta_Z1_M500, Mul_eta_Z1_M500 = muVBFvars(Z1_M500_df_mu)
m_T_Z1_M1000, m_jj_Z1_M1000, Delta_eta_Z1_M1000, Mul_eta_Z1_M1000 = muVBFvars(Z1_M1000_df_mu)
m_T_Z1_M3000, m_jj_Z1_M3000, Delta_eta_Z1_M3000, Mul_eta_Z1_M3000 = muVBFvars(Z1_M3000_df_mu)

Z2_M500_df_mu = basic_allch_cuts(Z2_M500_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 0, n_mu = 1, pt_mu = 25)
Z2_M1000_df_mu = basic_allch_cuts(Z2_M1000_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 0, n_mu = 1, pt_mu = 25)
Z2_M3000_df_mu = basic_allch_cuts(Z2_M3000_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 0, n_mu = 1, pt_mu = 25)

m_T_Z2_M500, m_jj_Z2_M500, Delta_eta_Z2_M500, Mul_eta_Z2_M500 = muVBFvars(Z2_M500_df_mu)
m_T_Z2_M1000, m_jj_Z2_M1000, Delta_eta_Z2_M1000, Mul_eta_Z2_M1000 = muVBFvars(Z2_M1000_df_mu)
m_T_Z2_M3000, m_jj_Z2_M3000, Delta_eta_Z2_M3000, Mul_eta_Z2_M3000 = muVBFvars(Z2_M3000_df_mu)

# %%
crazy_plotter([Z1_M500_df_mu, Z1_M1000_df_mu, Z1_M3000_df_mu, Z2_M500_df_mu, Z2_M1000_df_mu, Z2_M3000_df_mu],"muon","0",
["Z1_M500","Z1_M1000","Z1_M3000","Z2_M500","Z2_M1000","Z2_M3000"],["r","k","g","m","b","c",])

# %%
crazy_plotter([Z1_M500_df_mu, Z1_M1000_df_mu, Z1_M3000_df_mu, Z2_M500_df_mu, Z2_M1000_df_mu, Z2_M3000_df_mu],"jet","0",
["Z1_M500","Z1_M1000","Z1_M3000","Z2_M500","Z2_M1000","Z2_M3000"],["r","k","g","m","b","c",])
crazy_plotter([Z1_M500_df_mu, Z1_M1000_df_mu, Z1_M3000_df_mu, Z2_M500_df_mu, Z2_M1000_df_mu, Z2_M3000_df_mu],"jet","1",
["Z1_M500","Z1_M1000","Z1_M3000","Z2_M500","Z2_M1000","Z2_M3000"],["r","k","g","m","b","c",])

# %%
plot_var([Z1_M500_df_mu, Z1_M1000_df_mu, Z1_M3000_df_mu, Z2_M500_df_mu, Z2_M1000_df_mu, Z2_M3000_df_mu], "missinget_met", 0, 5000, 60, 
["Z1_M500","Z1_M1000","Z1_M3000","Z2_M500","Z2_M1000","Z2_M3000"], ["r","k","g","m","b","c",], r"$p_T^{miss}$ [GeV]", size = 14)

# %%
#m_jj_Z1_M500, m_T_Z1_M500, Delta_eta_Z1_M500, Mul_eta_Z1_M500
plot_ser([m_jj_Z1_M500, m_jj_Z1_M1000, m_jj_Z1_M3000, m_jj_Z2_M500, m_jj_Z2_M1000, m_jj_Z2_M3000], 50, 5000, 40, 
["Z1_M500","Z1_M1000","Z1_M3000","Z2_M500","Z2_M1000","Z2_M3000"],["r","k","g","m","b","c",], r"$m_{jj}$ [GeV]", size = 14)
plot_ser([m_T_Z1_M500, m_T_Z1_M1000, m_T_Z1_M3000, m_T_Z2_M500, m_T_Z2_M1000, m_T_Z2_M3000], 50, 5000, 40, 
["Z1_M500","Z1_M1000","Z1_M3000","Z2_M500","Z2_M1000","Z2_M3000"],["r","k","g","m","b","c",], r"$m_{T}$ [GeV]", size = 14)
plot_ser([Delta_eta_Z1_M500, Delta_eta_Z1_M1000, Delta_eta_Z1_M3000, Delta_eta_Z2_M500, Delta_eta_Z2_M1000, Delta_eta_Z2_M3000], 0, 10, 40, 
["Z1_M500","Z1_M1000","Z1_M3000","Z2_M500","Z2_M1000","Z2_M3000"],["r","k","g","m","b","c",], r"$\Delta\eta_{jj}$ [GeV]", size = 14)
plot_ser([Mul_eta_Z1_M500, Mul_eta_Z1_M1000, Mul_eta_Z1_M3000, Mul_eta_Z2_M500, Mul_eta_Z2_M1000, Mul_eta_Z2_M3000], -30, 30, 60, 
["Z1_M500","Z1_M1000","Z1_M3000","Z2_M500","Z2_M1000","Z2_M3000"],["r","k","g","m","b","c",], r"$\eta(j_{1})\eta(j_{2})$ [GeV]", size = 14)

# %% [markdown]
# # Electron Channel

# %%
Z1_M500_df_e = basic_allch_cuts(Z1_M500_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 1, n_mu = 0, pt_e = 25)
Z1_M1000_df_e = basic_allch_cuts(Z1_M1000_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 1, n_mu = 0, pt_e = 25)
Z1_M3000_df_e = basic_allch_cuts(Z1_M3000_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 1, n_mu = 0, pt_e = 25)

m_T_Z1_M500_e, m_jj_Z1_M500_e, Delta_eta_Z1_M500_e, Mul_eta_Z1_M500_e = eVBFvars(Z1_M500_df_e)
m_T_Z1_M1000_e, m_jj_Z1_M1000_e, Delta_eta_Z1_M1000_e, Mul_eta_Z1_M1000_e = eVBFvars(Z1_M1000_df_e)
m_T_Z1_M3000_e, m_jj_Z1_M3000_e, Delta_eta_Z1_M3000_e, Mul_eta_Z1_M3000_e = eVBFvars(Z1_M3000_df_e)

Z2_M500_df_e = basic_allch_cuts(Z2_M500_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 1, n_mu = 0, pt_e = 25)
Z2_M1000_df_e = basic_allch_cuts(Z2_M1000_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 1, n_mu = 0, pt_e = 25)
Z2_M3000_df_e = basic_allch_cuts(Z2_M3000_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 1, n_mu = 0, pt_e = 25)

m_T_Z2_M500_e, m_jj_Z2_M500_e, Delta_eta_Z2_M500_e, Mul_eta_Z2_M500_e = eVBFvars(Z2_M500_df_e)
m_T_Z2_M1000_e, m_jj_Z2_M1000_e, Delta_eta_Z2_M1000_e, Mul_eta_Z2_M1000_e = eVBFvars(Z2_M1000_df_e)
m_T_Z2_M3000_e, m_jj_Z2_M3000_e, Delta_eta_Z2_M3000_e, Mul_eta_Z2_M3000_e = eVBFvars(Z2_M3000_df_e)

# %%
crazy_plotter([Z1_M500_df_e, Z1_M1000_df_e, Z1_M3000_df_e, Z2_M500_df_e, Z2_M1000_df_e, Z2_M3000_df_e],"electron","0",
["Z1_M500","Z1_M1000","Z1_M3000","Z2_M500","Z2_M1000","Z2_M3000"],["r","k","g","m","b","c",])

# %%
crazy_plotter([Z1_M500_df_e, Z1_M1000_df_e, Z1_M3000_df_e, Z2_M500_df_e, Z2_M1000_df_e, Z2_M3000_df_e],"jet","0",
["Z1_M500","Z1_M1000","Z1_M3000","Z2_M500","Z2_M1000","Z2_M3000"],["r","k","g","m","b","c",])
crazy_plotter([Z1_M500_df_e, Z1_M1000_df_e, Z1_M3000_df_e, Z2_M500_df_e, Z2_M1000_df_e, Z2_M3000_df_e],"jet","1",
["Z1_M500","Z1_M1000","Z1_M3000","Z2_M500","Z2_M1000","Z2_M3000"],["r","k","g","m","b","c",])

# %%
plot_var([Z1_M500_df_e, Z1_M1000_df_e, Z1_M3000_df_e, Z2_M500_df_e, Z2_M1000_df_e, Z2_M3000_df_e], "missinget_met", 0, 5000, 60, 
["Z1_M500","Z1_M1000","Z1_M3000","Z2_M500","Z2_M1000","Z2_M3000"], ["r","k","g","m","b","c",], r"$p_T^{miss}$ [GeV]", size = 14)
plot_ser([m_jj_Z1_M500_e, m_jj_Z1_M1000_e, m_jj_Z1_M3000_e, m_jj_Z2_M500_e, m_jj_Z2_M1000_e, m_jj_Z2_M3000_e], 50, 5000, 40, 
["Z1_M500","Z1_M1000","Z1_M3000","Z2_M500","Z2_M1000","Z2_M3000"],["r","k","g","m","b","c",], r"$m_{jj}$ [GeV]", size = 14)
plot_ser([m_T_Z1_M500_e, m_T_Z1_M1000_e, m_T_Z1_M3000_e, m_T_Z2_M500_e, m_T_Z2_M1000_e, m_T_Z2_M3000_e], 50, 5000, 40, 
["Z1_M500","Z1_M1000","Z1_M3000","Z2_M500","Z2_M1000","Z2_M3000"],["r","k","g","m","b","c",], r"$m_{T}$ [GeV]", size = 14)
plot_ser([Delta_eta_Z1_M500_e, Delta_eta_Z1_M1000_e, Delta_eta_Z1_M3000_e, Delta_eta_Z2_M500_e, Delta_eta_Z2_M1000_e, Delta_eta_Z2_M3000_e], 0, 10, 40, 
["Z1_M500","Z1_M1000","Z1_M3000","Z2_M500","Z2_M1000","Z2_M3000"],["r","k","g","m","b","c",], r"$\Delta\eta_{jj}$ [GeV]", size = 14)
plot_ser([Mul_eta_Z1_M500_e, Mul_eta_Z1_M1000_e, Mul_eta_Z1_M3000_e, Mul_eta_Z2_M500_e, Mul_eta_Z2_M1000_e, Mul_eta_Z2_M3000], -30, 30, 60, 
["Z1_M500","Z1_M1000","Z1_M3000","Z2_M500","Z2_M1000","Z2_M3000"],["r","k","g","m","b","c",], r"$\eta(j_{1})\eta(j_{2})$ [GeV]", size = 14)
