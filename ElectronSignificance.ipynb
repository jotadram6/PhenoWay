# %%
from AnasWorld import *

# %% [markdown]
# # Electron Channel

# %%
Z1_M1000_df = pd.read_csv("../Wprime_VBF_gWWpZ1.csv")
Bkg_W_df = pd.read_csv("../Wbkg_15032022.csv")
Bkg_ttbar_df = pd.read_csv("../TTbarbkg_15032022.csv")
Bkg_WW_df = pd.read_csv("../WWbkg_28032022.csv")
Bkg_WZ1_df = pd.read_csv("../WZ1_15032022.csv")
Bkg_WZ2_df = pd.read_csv("../WZ2_15032022.csv")

# %%
S_I=Z1_M1000_df.shape[0]
W_I=Bkg_W_df.shape[0]
TTbar_I=Bkg_ttbar_df.shape[0]
WW_I=Bkg_WW_df.shape[0]
WZ1_I=Bkg_WZ1_df.shape[0]
WZ2_I=Bkg_WZ2_df.shape[0]

print(S_I,W_I,TTbar_I,WW_I,WZ1_I,WZ2_I)
# Out:
# 50000 2200000 1100000 2100000 100000 100000

# %%
S1_df_e = basic_allch_cuts(Z1_M1000_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 1, n_mu = 0, pt_e = 25)
m_T_S, m_jj_S, Delta_eta_S, Mul_eta_S = eVBFvars(S1_df_e)
W_df_e = basic_allch_cuts(Bkg_W_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 1, n_mu = 0, pt_e = 25)
m_T_W, m_jj_W, Delta_eta_W, Mul_eta_W = eVBFvars(W_df_e)
TTbar_df_e = basic_allch_cuts(Bkg_ttbar_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 1, n_mu = 0, pt_e = 25)
m_T_ttbar, m_jj_ttbar, Delta_eta_ttbar, Mul_eta_ttbar = eVBFvars(TTbar_df_e)
WW_df_e = basic_allch_cuts(Bkg_WW_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 1, n_mu = 0, pt_e = 25)
m_T_WW, m_jj_WW, Delta_eta_WW, Mul_eta_WW = eVBFvars(WW_df_e)
WZ1_df_e = basic_allch_cuts(Bkg_WZ1_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 1, n_mu = 0, pt_e = 25)
m_T_WZ1, m_jj_WZ1, Delta_eta_WZ1, Mul_eta_WZ1 = eVBFvars(WZ1_df_e)
WZ2_df_e = basic_allch_cuts(Bkg_WZ2_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 1, n_mu = 0, pt_e = 25)
m_T_WZ2, m_jj_WZ2, Delta_eta_WZ2, Mul_eta_WZ2 = eVBFvars(WZ2_df_e)

# %%
S_0=S1_df_e.shape[0]
W_0=W_df_e.shape[0]
TTbar_0=TTbar_df_e.shape[0]
WW_0=WW_df_e.shape[0]
WZ1_0=WZ1_df_e.shape[0]
WZ2_0=WZ2_df_e.shape[0]

print(S_0,W_0,TTbar_0,WW_0,WZ1_0,WZ2_0)
# Out:
# 3420 272698 159927 117143 6505 15388

# %%
#Cross sections in pb
S_xs = 0.1
W_xs = 6.406
TTbar_xs = 1.675
WW_xs = 0.05653
WZ1_xs = 0.001198
WZ2_xs = 0.04195

#Lumi 
lumi=150000

#Weights
W_S = S_xs*lumi/Z1_M1000_df.shape[0]
W_W = W_xs*lumi/Bkg_W_df.shape[0]
W_TTbar = TTbar_xs*lumi/Bkg_ttbar_df.shape[0]
W_WW = WW_xs*lumi/Bkg_WW_df.shape[0]
W_WZ1 = WZ1_xs*lumi/Bkg_WZ1_df.shape[0]
W_WZ2 = WZ2_xs*lumi/Bkg_WZ2_df.shape[0]

# %% [markdown]
# ## VBF variables

# %%
plot_ser([Mul_eta_S, Mul_eta_W, Mul_eta_ttbar, Mul_eta_WW, Mul_eta_WZ1, Mul_eta_WZ2], -20, 20, 60, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$\eta(j_{1})\eta(j_{2})$ [GeV]", size = 14)
plot_ser([Delta_eta_S, Delta_eta_W, Delta_eta_ttbar, Delta_eta_WW, Delta_eta_WZ1, Delta_eta_WZ2], 0, 10, 40, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$\Delta \eta(j_{0}, j_{1})$ ", size = 14)
plot_ser([m_jj_S, m_jj_W, m_jj_ttbar, m_jj_WW, m_jj_WZ1, m_jj_WZ2], 0, 5000, 50, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$m(j_{0}, j_{1})$ ", size = 14)

# %%
plot_significances(m_jj_S, [m_jj_W, m_jj_ttbar, m_jj_WW, m_jj_WZ1, m_jj_WZ2], 
series_gt, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 5000, 50], r"m(j_{0}, j_{1}) [GeV]")

# %%
plot_significances(Delta_eta_S, [Delta_eta_W, Delta_eta_ttbar, Delta_eta_WW, Delta_eta_WZ1, Delta_eta_WZ2], 
series_gt, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 10, 40], r"\Delta \eta(j_{0}, j_{1})")
# Out:
# /cms/Jose/VBFWprime/PhenoWay/AnasWorld.py:286: RuntimeWarning: invalid value encountered in true_divide
#   sign1 = S/np.sqrt(S+TotB)

# %% [markdown]
# ## Selecting events with jets in opposite hemispheres

# %%
Sig_Mask_1=Mul_eta_S < 0
S1_df_e = S1_df_e[Sig_Mask_1]; m_T_S=m_T_S[Sig_Mask_1]; m_jj_S=m_jj_S[Sig_Mask_1]; Delta_eta_S=Delta_eta_S[Sig_Mask_1]; Mul_eta_S=Mul_eta_S[Sig_Mask_1]

W_Mask_1=Mul_eta_W < 0
W_df_e = W_df_e[W_Mask_1]; m_T_W=m_T_W[W_Mask_1]; m_jj_W=m_jj_W[W_Mask_1]; Delta_eta_W=Delta_eta_W[W_Mask_1]; Mul_eta_W=Mul_eta_W[W_Mask_1]

TTbar_Mask_1=Mul_eta_ttbar < 0
TTbar_df_e = TTbar_df_e[TTbar_Mask_1]; m_T_ttbar=m_T_ttbar[TTbar_Mask_1]; m_jj_ttbar=m_jj_ttbar[TTbar_Mask_1]; Delta_eta_ttbar=Delta_eta_ttbar[TTbar_Mask_1]; Mul_eta_ttbar=Mul_eta_ttbar[TTbar_Mask_1]

WW_Mask_1=Mul_eta_WW < 0
WW_df_e = WW_df_e[WW_Mask_1]; m_T_WW=m_T_WW[WW_Mask_1]; m_jj_WW=m_jj_WW[WW_Mask_1]; Delta_eta_WW=Delta_eta_WW[WW_Mask_1]; Mul_eta_WW=Mul_eta_WW[WW_Mask_1]

WZ1_Mask_1=Mul_eta_WZ1 < 0
WZ1_df_e = WZ1_df_e[WZ1_Mask_1]; m_T_WZ1=m_T_WZ1[WZ1_Mask_1]; m_jj_WZ1=m_jj_WZ1[WZ1_Mask_1]; Delta_eta_WZ1=Delta_eta_WZ1[WZ1_Mask_1]; Mul_eta_WZ1=Mul_eta_WZ1[WZ1_Mask_1]

WZ2_Mask_1=Mul_eta_WZ2 < 0
WZ2_df_e = WZ2_df_e[WZ2_Mask_1]; m_T_WZ2=m_T_WZ2[WZ2_Mask_1]; m_jj_WZ2=m_jj_WZ2[WZ2_Mask_1]; Delta_eta_WZ2=Delta_eta_WZ2[WZ2_Mask_1]; Mul_eta_WZ2=Mul_eta_WZ2[WZ2_Mask_1]

S_1=S1_df_e.shape[0]
W_1=W_df_e.shape[0]
TTbar_1=TTbar_df_e.shape[0]
WW_1=WW_df_e.shape[0]
WZ1_1=WZ1_df_e.shape[0]
WZ2_1=WZ2_df_e.shape[0]

print(S_1,W_1,TTbar_1,WW_1,WZ1_1,WZ2_1)
# Out:
# 2506 122847 47863 38604 2095 7143

# %%
plot_significances(m_jj_S, [m_jj_W, m_jj_ttbar, m_jj_WW, m_jj_WZ1, m_jj_WZ2], 
series_gt, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 5000, 25], r"m(j_{0}, j_{1}) [GeV]")

# %%
plot_significances(Delta_eta_S, [Delta_eta_W, Delta_eta_ttbar, Delta_eta_WW, Delta_eta_WZ1, Delta_eta_WZ2], 
series_gt, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 10, 40], r"\Delta \eta(j_{0}, j_{1})")
# Out:
# /cms/Jose/VBFWprime/PhenoWay/AnasWorld.py:286: RuntimeWarning: invalid value encountered in true_divide
#   sign1 = S/np.sqrt(S+TotB)

# %% [markdown]
# ## Selecting events on mjj

# %%
m_jj_cut = 1000

Sig_Mask_1= (m_jj_S > m_jj_cut)
S1_df_e = S1_df_e[Sig_Mask_1]; m_T_S=m_T_S[Sig_Mask_1]; m_jj_S=m_jj_S[Sig_Mask_1]; Delta_eta_S=Delta_eta_S[Sig_Mask_1]; Mul_eta_S=Mul_eta_S[Sig_Mask_1]

W_Mask_1=(m_jj_W > m_jj_cut)
W_df_e = W_df_e[W_Mask_1]; m_T_W=m_T_W[W_Mask_1]; m_jj_W=m_jj_W[W_Mask_1]; Delta_eta_W=Delta_eta_W[W_Mask_1]; Mul_eta_W=Mul_eta_W[W_Mask_1]

TTbar_Mask_1=(m_jj_ttbar > m_jj_cut)
TTbar_df_e = TTbar_df_e[TTbar_Mask_1]; m_T_ttbar=m_T_ttbar[TTbar_Mask_1]; m_jj_ttbar=m_jj_ttbar[TTbar_Mask_1]; Delta_eta_ttbar=Delta_eta_ttbar[TTbar_Mask_1]; Mul_eta_ttbar=Mul_eta_ttbar[TTbar_Mask_1]

WW_Mask_1=(m_jj_WW > m_jj_cut)
WW_df_e = WW_df_e[WW_Mask_1]; m_T_WW=m_T_WW[WW_Mask_1]; m_jj_WW=m_jj_WW[WW_Mask_1]; Delta_eta_WW=Delta_eta_WW[WW_Mask_1]; Mul_eta_WW=Mul_eta_WW[WW_Mask_1]

WZ1_Mask_1=(m_jj_WZ1 > m_jj_cut)
WZ1_df_e = WZ1_df_e[WZ1_Mask_1]; m_T_WZ1=m_T_WZ1[WZ1_Mask_1]; m_jj_WZ1=m_jj_WZ1[WZ1_Mask_1]; Delta_eta_WZ1=Delta_eta_WZ1[WZ1_Mask_1]; Mul_eta_WZ1=Mul_eta_WZ1[WZ1_Mask_1]

WZ2_Mask_1=(m_jj_WZ2 > m_jj_cut)
WZ2_df_e = WZ2_df_e[WZ2_Mask_1]; m_T_WZ2=m_T_WZ2[WZ2_Mask_1]; m_jj_WZ2=m_jj_WZ2[WZ2_Mask_1]; Delta_eta_WZ2=Delta_eta_WZ2[WZ2_Mask_1]; Mul_eta_WZ2=Mul_eta_WZ2[WZ2_Mask_1]

S_2=S1_df_e.shape[0]
W_2=W_df_e.shape[0]
TTbar_2=TTbar_df_e.shape[0]
WW_2=WW_df_e.shape[0]
WZ1_2=WZ1_df_e.shape[0]
WZ2_2=WZ2_df_e.shape[0]

print(S_2,W_2,TTbar_2,WW_2,WZ1_2,WZ2_2)
# Out:
# 1625 24346 5926 5591 287 1416

# %%
plot_significances(Delta_eta_S, [Delta_eta_W, Delta_eta_ttbar, Delta_eta_WW, Delta_eta_WZ1, Delta_eta_WZ2], 
series_gt, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 10, 40], r"\Delta \eta(j_{0}, j_{1})")
# Out:
# /cms/Jose/VBFWprime/PhenoWay/AnasWorld.py:286: RuntimeWarning: invalid value encountered in true_divide
#   sign1 = S/np.sqrt(S+TotB)

# %% [markdown]
# ## Cutting on delta eta jj

# %%
DeltaEta_jj_cut = 4.0

Sig_Mask_1= (Delta_eta_S > DeltaEta_jj_cut)
S1_df_e = S1_df_e[Sig_Mask_1]; m_T_S=m_T_S[Sig_Mask_1]; m_jj_S=m_jj_S[Sig_Mask_1]; Delta_eta_S=Delta_eta_S[Sig_Mask_1]; Mul_eta_S=Mul_eta_S[Sig_Mask_1]

W_Mask_1=(Delta_eta_W > DeltaEta_jj_cut)
W_df_e = W_df_e[W_Mask_1]; m_T_W=m_T_W[W_Mask_1]; m_jj_W=m_jj_W[W_Mask_1]; Delta_eta_W=Delta_eta_W[W_Mask_1]; Mul_eta_W=Mul_eta_W[W_Mask_1]

TTbar_Mask_1=(Delta_eta_ttbar > DeltaEta_jj_cut)
TTbar_df_e = TTbar_df_e[TTbar_Mask_1]; m_T_ttbar=m_T_ttbar[TTbar_Mask_1]; m_jj_ttbar=m_jj_ttbar[TTbar_Mask_1]; Delta_eta_ttbar=Delta_eta_ttbar[TTbar_Mask_1]; Mul_eta_ttbar=Mul_eta_ttbar[TTbar_Mask_1]

WW_Mask_1=(Delta_eta_WW > DeltaEta_jj_cut)
WW_df_e = WW_df_e[WW_Mask_1]; m_T_WW=m_T_WW[WW_Mask_1]; m_jj_WW=m_jj_WW[WW_Mask_1]; Delta_eta_WW=Delta_eta_WW[WW_Mask_1]; Mul_eta_WW=Mul_eta_WW[WW_Mask_1]

WZ1_Mask_1=(Delta_eta_WZ1 > DeltaEta_jj_cut)
WZ1_df_e = WZ1_df_e[WZ1_Mask_1]; m_T_WZ1=m_T_WZ1[WZ1_Mask_1]; m_jj_WZ1=m_jj_WZ1[WZ1_Mask_1]; Delta_eta_WZ1=Delta_eta_WZ1[WZ1_Mask_1]; Mul_eta_WZ1=Mul_eta_WZ1[WZ1_Mask_1]

WZ2_Mask_1=(Delta_eta_WZ2 > DeltaEta_jj_cut)
WZ2_df_e = WZ2_df_e[WZ2_Mask_1]; m_T_WZ2=m_T_WZ2[WZ2_Mask_1]; m_jj_WZ2=m_jj_WZ2[WZ2_Mask_1]; Delta_eta_WZ2=Delta_eta_WZ2[WZ2_Mask_1]; Mul_eta_WZ2=Mul_eta_WZ2[WZ2_Mask_1]

S_3=S1_df_e.shape[0]
W_3=W_df_e.shape[0]
TTbar_3=TTbar_df_e.shape[0]
WW_3=WW_df_e.shape[0]
WZ1_3=WZ1_df_e.shape[0]
WZ2_3=WZ2_df_e.shape[0]

print(S_3,W_3,TTbar_3,WW_3,WZ1_3,WZ2_3)
# Out:
# 1425 4929 1239 1104 61 284

# %% [markdown]
# ## Wprime variables

# %%
plot_var([S1_df_e, W_df_e, TTbar_df_e, WW_df_e, WZ1_df_e, WZ2_df_e], "electron_pt0", 20, 1000, 30, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$p_{T}(e)$ [GeV]", size = 14)
plot_var([S1_df_e, W_df_e, TTbar_df_e, WW_df_e, WZ1_df_e, WZ2_df_e], "missinget_met", 20, 1000, 30, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$p_{T}^{miss}$ [GeV]", size = 14)
plot_var([S1_df_e, W_df_e, TTbar_df_e, WW_df_e, WZ1_df_e, WZ2_df_e], "Delta_phi_e_Met", 0, 4, 20, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$|\Delta \phi(e, p_{T}^{miss})|$", size = 14)

# %%
S1_df_e["emet_ptratio"] = S1_df_e["electron_pt0"]/S1_df_e["missinget_met"]
W_df_e["emet_ptratio"] = W_df_e["electron_pt0"]/W_df_e["missinget_met"]
TTbar_df_e["emet_ptratio"] = TTbar_df_e["electron_pt0"]/TTbar_df_e["missinget_met"]
WW_df_e["emet_ptratio"] = WW_df_e["electron_pt0"]/WW_df_e["missinget_met"]
WZ1_df_e["emet_ptratio"] = WZ1_df_e["electron_pt0"]/WZ1_df_e["missinget_met"]
WZ2_df_e["emet_ptratio"] = WZ2_df_e["electron_pt0"]/WZ2_df_e["missinget_met"]

# %%
plot_var([S1_df_e, W_df_e, TTbar_df_e, WW_df_e, WZ1_df_e, WZ2_df_e], "emet_ptratio", 0, 4, 40, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$p_{T}(e)/p_{T}^{miss}$", size = 14)

# %%
plot_significances(S1_df_e, [W_df_e, TTbar_df_e, WW_df_e, WZ1_df_e, WZ2_df_e], 
pt_ele, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [20, 1000, 30], r"p_T(e)")

# %%
plot_significances(S1_df_e, [W_df_e, TTbar_df_e, WW_df_e, WZ1_df_e, WZ2_df_e], 
pt_miss, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [20, 1000, 30], r"p_T^{miss}")

# %%
plot_significances(S1_df_e, [W_df_e, TTbar_df_e, WW_df_e, WZ1_df_e, WZ2_df_e], 
phi_e_met, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 4, 20], r"\Delta \phi(e, p_{T}^{miss})")
# Out:
# /cms/Jose/VBFWprime/PhenoWay/AnasWorld.py:286: RuntimeWarning: invalid value encountered in true_divide
#   sign1 = S/np.sqrt(S+TotB)

# %%
plot_significances(S1_df_e, [W_df_e, TTbar_df_e, WW_df_e, WZ1_df_e, WZ2_df_e], 
emet_ptratio, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 4, 40], r"p_{T}(e)/p_{T}^{miss}")

# %% [markdown]
# ## Cutting on the muon pT

# %%
epT=200

Sig_Mask_1=S1_df_e.electron_pt0 > epT
S1_df_e = S1_df_e[Sig_Mask_1]; m_T_S=m_T_S[Sig_Mask_1]; m_jj_S=m_jj_S[Sig_Mask_1]; Delta_eta_S=Delta_eta_S[Sig_Mask_1]; Mul_eta_S=Mul_eta_S[Sig_Mask_1]

W_Mask_1=W_df_e.electron_pt0 > epT
W_df_e = W_df_e[W_Mask_1]; m_T_W=m_T_W[W_Mask_1]; m_jj_W=m_jj_W[W_Mask_1]; Delta_eta_W=Delta_eta_W[W_Mask_1]; Mul_eta_W=Mul_eta_W[W_Mask_1]

TTbar_Mask_1=TTbar_df_e.electron_pt0 > epT
TTbar_df_e = TTbar_df_e[TTbar_Mask_1]; m_T_ttbar=m_T_ttbar[TTbar_Mask_1]; m_jj_ttbar=m_jj_ttbar[TTbar_Mask_1]; Delta_eta_ttbar=Delta_eta_ttbar[TTbar_Mask_1]; Mul_eta_ttbar=Mul_eta_ttbar[TTbar_Mask_1]

WW_Mask_1=WW_df_e.electron_pt0 > epT
WW_df_e = WW_df_e[WW_Mask_1]; m_T_WW=m_T_WW[WW_Mask_1]; m_jj_WW=m_jj_WW[WW_Mask_1]; Delta_eta_WW=Delta_eta_WW[WW_Mask_1]; Mul_eta_WW=Mul_eta_WW[WW_Mask_1]

WZ1_Mask_1=WZ1_df_e.electron_pt0 > epT
WZ1_df_e = WZ1_df_e[WZ1_Mask_1]; m_T_WZ1=m_T_WZ1[WZ1_Mask_1]; m_jj_WZ1=m_jj_WZ1[WZ1_Mask_1]; Delta_eta_WZ1=Delta_eta_WZ1[WZ1_Mask_1]; Mul_eta_WZ1=Mul_eta_WZ1[WZ1_Mask_1]

WZ2_Mask_1=WZ2_df_e.electron_pt0 > epT
WZ2_df_e = WZ2_df_e[WZ2_Mask_1]; m_T_WZ2=m_T_WZ2[WZ2_Mask_1]; m_jj_WZ2=m_jj_WZ2[WZ2_Mask_1]; Delta_eta_WZ2=Delta_eta_WZ2[WZ2_Mask_1]; Mul_eta_WZ2=Mul_eta_WZ2[WZ2_Mask_1]

S_4=S1_df_e.shape[0]
W_4=W_df_e.shape[0]
TTbar_4=TTbar_df_e.shape[0]
WW_4=WW_df_e.shape[0]
WZ1_4=WZ1_df_e.shape[0]
WZ2_4=WZ2_df_e.shape[0]

print(S_4,W_4,TTbar_4,WW_4,WZ1_4,WZ2_4)
# Out:
# 1269 215 49 73 3 24

# %%
plot_significances(S1_df_e, [W_df_e, TTbar_df_e, WW_df_e, WZ1_df_e, WZ2_df_e], 
pt_miss, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [20, 1000, 30], r"p_T^{miss}")

# %%
plot_significances(S1_df_e, [W_df_e, TTbar_df_e, WW_df_e, WZ1_df_e, WZ2_df_e], 
phi_e_met, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 4, 20], r"\Delta \phi(e, p_{T}^{miss})")
# Out:
# /cms/Jose/VBFWprime/PhenoWay/AnasWorld.py:286: RuntimeWarning: invalid value encountered in true_divide
#   sign1 = S/np.sqrt(S+TotB)

# %%
plot_significances(S1_df_e, [W_df_e, TTbar_df_e, WW_df_e, WZ1_df_e, WZ2_df_e], 
emet_ptratio, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 4, 40], r"p_{T}(e)/p_{T}^{miss}")

# %% [markdown]
# ## Cutting on MET

# %%
MET=200

Sig_Mask_1=S1_df_e.missinget_met > MET
S1_df_e = S1_df_e[Sig_Mask_1]; m_T_S=m_T_S[Sig_Mask_1]; m_jj_S=m_jj_S[Sig_Mask_1]; Delta_eta_S=Delta_eta_S[Sig_Mask_1]; Mul_eta_S=Mul_eta_S[Sig_Mask_1]

W_Mask_1=W_df_e.missinget_met > MET
W_df_e = W_df_e[W_Mask_1]; m_T_W=m_T_W[W_Mask_1]; m_jj_W=m_jj_W[W_Mask_1]; Delta_eta_W=Delta_eta_W[W_Mask_1]; Mul_eta_W=Mul_eta_W[W_Mask_1]

TTbar_Mask_1=TTbar_df_e.missinget_met > MET
TTbar_df_e = TTbar_df_e[TTbar_Mask_1]; m_T_ttbar=m_T_ttbar[TTbar_Mask_1]; m_jj_ttbar=m_jj_ttbar[TTbar_Mask_1]; Delta_eta_ttbar=Delta_eta_ttbar[TTbar_Mask_1]; Mul_eta_ttbar=Mul_eta_ttbar[TTbar_Mask_1]

WW_Mask_1=WW_df_e.missinget_met > MET
WW_df_e = WW_df_e[WW_Mask_1]; m_T_WW=m_T_WW[WW_Mask_1]; m_jj_WW=m_jj_WW[WW_Mask_1]; Delta_eta_WW=Delta_eta_WW[WW_Mask_1]; Mul_eta_WW=Mul_eta_WW[WW_Mask_1]

WZ1_Mask_1=WZ1_df_e.missinget_met > MET
WZ1_df_e = WZ1_df_e[WZ1_Mask_1]; m_T_WZ1=m_T_WZ1[WZ1_Mask_1]; m_jj_WZ1=m_jj_WZ1[WZ1_Mask_1]; Delta_eta_WZ1=Delta_eta_WZ1[WZ1_Mask_1]; Mul_eta_WZ1=Mul_eta_WZ1[WZ1_Mask_1]

WZ2_Mask_1=WZ2_df_e.missinget_met > MET
WZ2_df_e = WZ2_df_e[WZ2_Mask_1]; m_T_WZ2=m_T_WZ2[WZ2_Mask_1]; m_jj_WZ2=m_jj_WZ2[WZ2_Mask_1]; Delta_eta_WZ2=Delta_eta_WZ2[WZ2_Mask_1]; Mul_eta_WZ2=Mul_eta_WZ2[WZ2_Mask_1]

S_5=S1_df_e.shape[0]
W_5=W_df_e.shape[0]
TTbar_5=TTbar_df_e.shape[0]
WW_5=WW_df_e.shape[0]
WZ1_5=WZ1_df_e.shape[0]
WZ2_5=WZ2_df_e.shape[0]

print(S_5,W_5,TTbar_5,WW_5,WZ1_5,WZ2_5)
# Out:
# 1237 172 41 56 3 19

# %%
plot_var([S1_df_e, W_df_e, TTbar_df_e, WW_df_e, WZ1_df_e, WZ2_df_e], "Delta_phi_e_Met", 0, 4, 20, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$|\Delta \phi(e, p_{T}^{miss})|$", size = 14)

# %%
plot_significances(S1_df_e, [W_df_e, TTbar_df_e, WW_df_e, WZ1_df_e, WZ2_df_e], 
phi_e_met, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 4, 20], r"\Delta \phi(e, p_{T}^{miss})")
# Out:
# /cms/Jose/VBFWprime/PhenoWay/AnasWorld.py:286: RuntimeWarning: invalid value encountered in true_divide
#   sign1 = S/np.sqrt(S+TotB)

# %% [markdown]
# ## Cutting on Delta phi mu met

# %%
DeltaPhieMet=1.0

Sig_Mask_1=S1_df_e.Delta_phi_e_Met > DeltaPhieMet
S1_df_e = S1_df_e[Sig_Mask_1]; m_T_S=m_T_S[Sig_Mask_1]; m_jj_S=m_jj_S[Sig_Mask_1]; Delta_eta_S=Delta_eta_S[Sig_Mask_1]; Mul_eta_S=Mul_eta_S[Sig_Mask_1]

W_Mask_1=W_df_e.Delta_phi_e_Met > DeltaPhieMet
W_df_e = W_df_e[W_Mask_1]; m_T_W=m_T_W[W_Mask_1]; m_jj_W=m_jj_W[W_Mask_1]; Delta_eta_W=Delta_eta_W[W_Mask_1]; Mul_eta_W=Mul_eta_W[W_Mask_1]

TTbar_Mask_1=TTbar_df_e.Delta_phi_e_Met > DeltaPhieMet
TTbar_df_e = TTbar_df_e[TTbar_Mask_1]; m_T_ttbar=m_T_ttbar[TTbar_Mask_1]; m_jj_ttbar=m_jj_ttbar[TTbar_Mask_1]; Delta_eta_ttbar=Delta_eta_ttbar[TTbar_Mask_1]; Mul_eta_ttbar=Mul_eta_ttbar[TTbar_Mask_1]

WW_Mask_1=WW_df_e.Delta_phi_e_Met > DeltaPhieMet
WW_df_e = WW_df_e[WW_Mask_1]; m_T_WW=m_T_WW[WW_Mask_1]; m_jj_WW=m_jj_WW[WW_Mask_1]; Delta_eta_WW=Delta_eta_WW[WW_Mask_1]; Mul_eta_WW=Mul_eta_WW[WW_Mask_1]

WZ1_Mask_1=WZ1_df_e.Delta_phi_e_Met > DeltaPhieMet
WZ1_df_e = WZ1_df_e[WZ1_Mask_1]; m_T_WZ1=m_T_WZ1[WZ1_Mask_1]; m_jj_WZ1=m_jj_WZ1[WZ1_Mask_1]; Delta_eta_WZ1=Delta_eta_WZ1[WZ1_Mask_1]; Mul_eta_WZ1=Mul_eta_WZ1[WZ1_Mask_1]

WZ2_Mask_1=WZ2_df_e.Delta_phi_e_Met > DeltaPhieMet
WZ2_df_e = WZ2_df_e[WZ2_Mask_1]; m_T_WZ2=m_T_WZ2[WZ2_Mask_1]; m_jj_WZ2=m_jj_WZ2[WZ2_Mask_1]; Delta_eta_WZ2=Delta_eta_WZ2[WZ2_Mask_1]; Mul_eta_WZ2=Mul_eta_WZ2[WZ2_Mask_1]

S_6=S1_df_e.shape[0]
W_6=W_df_e.shape[0]
TTbar_6=TTbar_df_e.shape[0]
WW_6=WW_df_e.shape[0]
WZ1_6=WZ1_df_e.shape[0]
WZ2_6=WZ2_df_e.shape[0]

print(S_6,W_6,TTbar_6,WW_6,WZ1_6,WZ2_6)
# Out:
# 1234 0 0 0 0 11

# %% [markdown]
# ## Final Significance and efficiencies

# %%
AllCuts=[
    np.array([S_0,W_0,TTbar_0,WW_0,WZ1_0,WZ2_0])*np.array([W_S, W_W, W_TTbar, W_WW, W_WZ1, W_WZ2]),
    np.array([S_1,W_1,TTbar_1,WW_1,WZ1_1,WZ2_1])*np.array([W_S, W_W, W_TTbar, W_WW, W_WZ1, W_WZ2]),
    np.array([S_2,W_2,TTbar_2,WW_2,WZ1_2,WZ2_2])*np.array([W_S, W_W, W_TTbar, W_WW, W_WZ1, W_WZ2]),
    np.array([S_3,W_3,TTbar_3,WW_3,WZ1_3,WZ2_3])*np.array([W_S, W_W, W_TTbar, W_WW, W_WZ1, W_WZ2]),
    np.array([S_4,W_4,TTbar_4,WW_4,WZ1_4,WZ2_4])*np.array([W_S, W_W, W_TTbar, W_WW, W_WZ1, W_WZ2]),
    np.array([S_5,W_5,TTbar_5,WW_5,WZ1_5,WZ2_5])*np.array([W_S, W_W, W_TTbar, W_WW, W_WZ1, W_WZ2]),
    np.array([S_6,W_6,TTbar_6,WW_6,WZ1_6,WZ2_6])*np.array([W_S, W_W, W_TTbar, W_WW, W_WZ1, W_WZ2])
]

# %%
PrintSign(AllCuts)
# Out:
# S/sqrt(S+B)
# Cut 1 2.5802457854440206
# Cut 2 2.9274982017926385
# Cut 3 4.3452521447183345
# Cut 4 7.957997089666686
# Cut 5 17.240395592719338
# Cut 6 17.359007352153817
# Cut 7 19.222619924632745

# %%
EfficiencyTables(AllCuts)
# Out:
# N-1 efficiencies:
# Cut 1 [73.27 45.05 29.93 32.95 32.21 46.42]
# Cut 2 [64.84 19.82 12.38 14.48 13.7  19.82]
# Cut 3 [87.69 20.25 20.91 19.75 21.25 20.06]
# Cut 4 [89.05  4.36  3.95  6.61  4.92  8.45]
# Cut 5 [ 97.48  80.    83.67  76.71 100.    79.17]
# Cut 6 [99.76  0.    0.    0.    0.   57.89]
# Cumulative efficiencies:
# Cut 1 [73.27 45.05 29.93 32.95 32.21 46.42]
# Cut 2 [47.51  8.93  3.71  4.77  4.41  9.2 ]
# Cut 3 [41.67  1.81  0.77  0.94  0.94  1.85]
# Cut 4 [3.711e+01 8.000e-02 3.000e-02 6.000e-02 5.000e-02 1.600e-01]
# Cut 5 [3.617e+01 6.000e-02 3.000e-02 5.000e-02 5.000e-02 1.200e-01]
# Cut 6 [36.08  0.    0.    0.    0.    0.07]

# %%
plot_ser([m_T_S, m_T_W, m_T_ttbar, m_T_WW, m_T_WZ1, m_T_WZ2], 0, 3000, 20, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$m_{T}$ [GeV]", size = 14)
# Out:
# /home/jose/.local/lib/python3.9/site-packages/mplhep/utils.py:263: RuntimeWarning: divide by zero encountered in double_scalars
#   self.flat_scale(1 / np.sum(self.values))
# /home/jose/.local/lib/python3.9/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# /home/jose/.local/lib/python3.9/site-packages/mplhep/utils.py:243: RuntimeWarning: invalid value encountered in multiply
#   self.values *= scale
# /home/jose/.local/lib/python3.9/site-packages/mplhep/utils.py:244: RuntimeWarning: invalid value encountered in multiply
#   self.yerr_lo *= scale
# /home/jose/.local/lib/python3.9/site-packages/mplhep/utils.py:245: RuntimeWarning: invalid value encountered in multiply
#   self.yerr_hi *= scale
# /home/jose/.local/lib/python3.9/site-packages/mplhep/utils.py:263: RuntimeWarning: divide by zero encountered in double_scalars
#   self.flat_scale(1 / np.sum(self.values))
# ...
