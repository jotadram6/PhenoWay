# %%
from AnasWorld import *

# %% [markdown]
# # Tau Channel

# %%
Z1_M1000_df = pd.read_csv("../Wprime_VBF_gWWpZ1.csv")
Bkg_W_df = pd.read_csv("../Wtaubkg_27032022.csv")
Bkg_ttbar_df = pd.read_csv("../TTbartaubkg_27032022.csv")
Bkg_WW_df = pd.read_csv("../WWtaubkg_29032022.csv")
Bkg_WZ1_df = pd.read_csv("../WZ1tau_29032022.csv")
Bkg_WZ2_df = pd.read_csv("../WZ2tau_29032022.csv")

# %%
S_I=Z1_M1000_df.shape[0]
W_I=Bkg_W_df.shape[0]
TTbar_I=Bkg_ttbar_df.shape[0]
WW_I=Bkg_WW_df.shape[0]
WZ1_I=Bkg_WZ1_df.shape[0]
WZ2_I=Bkg_WZ2_df.shape[0]

print(S_I,W_I,TTbar_I,WW_I,WZ1_I,WZ2_I)
# Out:
# 50000 1600000 1600000 2000000 100000 100000

# %%
S1_df_tau = basic_allch_cuts(Z1_M1000_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 1, n_e = 0, n_mu = 0, pt_tau = 30)
m_T_S, m_jj_S, Delta_eta_S, Mul_eta_S = tauVBFvars(S1_df_tau)
W_df_tau = basic_allch_cuts(Bkg_W_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 1, n_e = 0, n_mu = 0, pt_tau = 30)
m_T_W, m_jj_W, Delta_eta_W, Mul_eta_W = tauVBFvars(W_df_tau)
TTbar_df_tau = basic_allch_cuts(Bkg_ttbar_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 1, n_e = 0, n_mu = 0, pt_tau = 30)
m_T_ttbar, m_jj_ttbar, Delta_eta_ttbar, Mul_eta_ttbar = tauVBFvars(TTbar_df_tau)
WW_df_tau = basic_allch_cuts(Bkg_WW_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 1, n_e = 0, n_mu = 0, pt_tau = 30)
m_T_WW, m_jj_WW, Delta_eta_WW, Mul_eta_WW = tauVBFvars(WW_df_tau)
WZ1_df_tau = basic_allch_cuts(Bkg_WZ1_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 1, n_e = 0, n_mu = 0, pt_tau = 30)
m_T_WZ1, m_jj_WZ1, Delta_eta_WZ1, Mul_eta_WZ1 = tauVBFvars(WZ1_df_tau)
WZ2_df_tau = basic_allch_cuts(Bkg_WZ2_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 1, n_e = 0, n_mu = 0, pt_tau = 30)
m_T_WZ2, m_jj_WZ2, Delta_eta_WZ2, Mul_eta_WZ2 = tauVBFvars(WZ2_df_tau)

# %%
#Saving CSV at baseline selection
S1_df_tau.to_csv("S1_df_tau.csv")
W_df_tau.to_csv("W_df_tau.csv")
TTbar_df_tau.to_csv("TTbar_df_tau.csv")
WW_df_tau.to_csv("WW_df_tau.csv")
WZ1_df_tau.to_csv("WZ1_df_tau.csv")
WZ2_df_tau.to_csv("WZ2_df_tau.csv")

# %%
S_0=S1_df_tau.shape[0]
W_0=W_df_tau.shape[0]
TTbar_0=TTbar_df_tau.shape[0]
WW_0=WW_df_tau.shape[0]
WZ1_0=WZ1_df_tau.shape[0]
WZ2_0=WZ2_df_tau.shape[0]

print(S_0,W_0,TTbar_0,WW_0,WZ1_0,WZ2_0)
# Out:
# 1562 156796 224074 84989 12583 5037

# %%
#Cross sections in pb
S_xs = 0.1
W_xs = 3.175
TTbar_xs = 0.8359
WW_xs = 0.02821
WZ1_xs = 0.005983
WZ2_xs = 0.02096

#Lumi 
lumi=150000

#Weights
W_S = S_xs*lumi/Z1_M1000_df.shape[0]
W_W = W_xs*lumi/Bkg_W_df.shape[0]
W_TTbar = TTbar_xs*lumi/Bkg_ttbar_df.shape[0]
W_WW = WW_xs*lumi/Bkg_WW_df.shape[0]
W_WZ1 = WZ1_xs*lumi/Bkg_WZ1_df.shape[0]
W_WZ2 = WZ2_xs*lumi/Bkg_WZ2_df.shape[0]

# %% [markdown]
# ## VBF variables

# %%
plot_ser([Mul_eta_S, Mul_eta_W, Mul_eta_ttbar, Mul_eta_WW, Mul_eta_WZ1, Mul_eta_WZ2], -20, 20, 60, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$\eta(j_{1})\eta(j_{2})$", size = 14)
plot_ser([Delta_eta_S, Delta_eta_W, Delta_eta_ttbar, Delta_eta_WW, Delta_eta_WZ1, Delta_eta_WZ2], 0, 10, 40, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$\Delta \eta(j_{0}, j_{1})$ ", size = 14)
plot_ser([m_jj_S, m_jj_W, m_jj_ttbar, m_jj_WW, m_jj_WZ1, m_jj_WZ2], 0, 5000, 50, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$m(j_{0}, j_{1})$ [GeV]", size = 14)

# %%
plot_significances(m_jj_S, [m_jj_W, m_jj_ttbar, m_jj_WW, m_jj_WZ1, m_jj_WZ2], 
series_gt, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 5000, 50], r"m(j_{0}, j_{1}) [GeV]")

# %%
plot_significances(Delta_eta_S, [Delta_eta_W, Delta_eta_ttbar, Delta_eta_WW, Delta_eta_WZ1, Delta_eta_WZ2], 
series_gt, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 8, 40], r"\Delta \eta(j_{0}, j_{1})")

# %% [markdown]
# ## Selecting events with jets in opposite hemispheres

# %%
Sig_Mask_1=Mul_eta_S < 0
S1_df_tau = S1_df_tau[Sig_Mask_1]; m_T_S=m_T_S[Sig_Mask_1]; m_jj_S=m_jj_S[Sig_Mask_1]; Delta_eta_S=Delta_eta_S[Sig_Mask_1]; Mul_eta_S=Mul_eta_S[Sig_Mask_1]

W_Mask_1=Mul_eta_W < 0
W_df_tau = W_df_tau[W_Mask_1]; m_T_W=m_T_W[W_Mask_1]; m_jj_W=m_jj_W[W_Mask_1]; Delta_eta_W=Delta_eta_W[W_Mask_1]; Mul_eta_W=Mul_eta_W[W_Mask_1]

TTbar_Mask_1=Mul_eta_ttbar < 0
TTbar_df_tau = TTbar_df_tau[TTbar_Mask_1]; m_T_ttbar=m_T_ttbar[TTbar_Mask_1]; m_jj_ttbar=m_jj_ttbar[TTbar_Mask_1]; Delta_eta_ttbar=Delta_eta_ttbar[TTbar_Mask_1]; Mul_eta_ttbar=Mul_eta_ttbar[TTbar_Mask_1]

WW_Mask_1=Mul_eta_WW < 0
WW_df_tau = WW_df_tau[WW_Mask_1]; m_T_WW=m_T_WW[WW_Mask_1]; m_jj_WW=m_jj_WW[WW_Mask_1]; Delta_eta_WW=Delta_eta_WW[WW_Mask_1]; Mul_eta_WW=Mul_eta_WW[WW_Mask_1]

WZ1_Mask_1=Mul_eta_WZ1 < 0
WZ1_df_tau = WZ1_df_tau[WZ1_Mask_1]; m_T_WZ1=m_T_WZ1[WZ1_Mask_1]; m_jj_WZ1=m_jj_WZ1[WZ1_Mask_1]; Delta_eta_WZ1=Delta_eta_WZ1[WZ1_Mask_1]; Mul_eta_WZ1=Mul_eta_WZ1[WZ1_Mask_1]

WZ2_Mask_1=Mul_eta_WZ2 < 0
WZ2_df_tau = WZ2_df_tau[WZ2_Mask_1]; m_T_WZ2=m_T_WZ2[WZ2_Mask_1]; m_jj_WZ2=m_jj_WZ2[WZ2_Mask_1]; Delta_eta_WZ2=Delta_eta_WZ2[WZ2_Mask_1]; Mul_eta_WZ2=Mul_eta_WZ2[WZ2_Mask_1]

S_1=S1_df_tau.shape[0]
W_1=W_df_tau.shape[0]
TTbar_1=TTbar_df_tau.shape[0]
WW_1=WW_df_tau.shape[0]
WZ1_1=WZ1_df_tau.shape[0]
WZ2_1=WZ2_df_tau.shape[0]

print(S_1,W_1,TTbar_1,WW_1,WZ1_1,WZ2_1)
# Out:
# 1114 69808 68140 28644 5707 1652

# %%
plot_significances(m_jj_S, [m_jj_W, m_jj_ttbar, m_jj_WW, m_jj_WZ1, m_jj_WZ2], 
series_gt, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 5000, 25], r"m(j_{0}, j_{1}) [GeV]")

# %%
plot_significances(Delta_eta_S, [Delta_eta_W, Delta_eta_ttbar, Delta_eta_WW, Delta_eta_WZ1, Delta_eta_WZ2], 
series_gt, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 8, 40], r"\Delta \eta(j_{0}, j_{1})")

# %% [markdown]
# ## Selecting events on mjj

# %%
m_jj_cut = 1000

Sig_Mask_1= (m_jj_S > m_jj_cut)
S1_df_tau = S1_df_tau[Sig_Mask_1]; m_T_S=m_T_S[Sig_Mask_1]; m_jj_S=m_jj_S[Sig_Mask_1]; Delta_eta_S=Delta_eta_S[Sig_Mask_1]; Mul_eta_S=Mul_eta_S[Sig_Mask_1]

W_Mask_1=(m_jj_W > m_jj_cut)
W_df_tau = W_df_tau[W_Mask_1]; m_T_W=m_T_W[W_Mask_1]; m_jj_W=m_jj_W[W_Mask_1]; Delta_eta_W=Delta_eta_W[W_Mask_1]; Mul_eta_W=Mul_eta_W[W_Mask_1]

TTbar_Mask_1=(m_jj_ttbar > m_jj_cut)
TTbar_df_tau = TTbar_df_tau[TTbar_Mask_1]; m_T_ttbar=m_T_ttbar[TTbar_Mask_1]; m_jj_ttbar=m_jj_ttbar[TTbar_Mask_1]; Delta_eta_ttbar=Delta_eta_ttbar[TTbar_Mask_1]; Mul_eta_ttbar=Mul_eta_ttbar[TTbar_Mask_1]

WW_Mask_1=(m_jj_WW > m_jj_cut)
WW_df_tau = WW_df_tau[WW_Mask_1]; m_T_WW=m_T_WW[WW_Mask_1]; m_jj_WW=m_jj_WW[WW_Mask_1]; Delta_eta_WW=Delta_eta_WW[WW_Mask_1]; Mul_eta_WW=Mul_eta_WW[WW_Mask_1]

WZ1_Mask_1=(m_jj_WZ1 > m_jj_cut)
WZ1_df_tau = WZ1_df_tau[WZ1_Mask_1]; m_T_WZ1=m_T_WZ1[WZ1_Mask_1]; m_jj_WZ1=m_jj_WZ1[WZ1_Mask_1]; Delta_eta_WZ1=Delta_eta_WZ1[WZ1_Mask_1]; Mul_eta_WZ1=Mul_eta_WZ1[WZ1_Mask_1]

WZ2_Mask_1=(m_jj_WZ2 > m_jj_cut)
WZ2_df_tau = WZ2_df_tau[WZ2_Mask_1]; m_T_WZ2=m_T_WZ2[WZ2_Mask_1]; m_jj_WZ2=m_jj_WZ2[WZ2_Mask_1]; Delta_eta_WZ2=Delta_eta_WZ2[WZ2_Mask_1]; Mul_eta_WZ2=Mul_eta_WZ2[WZ2_Mask_1]

S_2=S1_df_tau.shape[0]
W_2=W_df_tau.shape[0]
TTbar_2=TTbar_df_tau.shape[0]
WW_2=WW_df_tau.shape[0]
WZ1_2=WZ1_df_tau.shape[0]
WZ2_2=WZ2_df_tau.shape[0]

print(S_2,W_2,TTbar_2,WW_2,WZ1_2,WZ2_2)
# Out:
# 691 13724 8974 4104 1109 249

# %%
plot_significances(Delta_eta_S, [Delta_eta_W, Delta_eta_ttbar, Delta_eta_WW, Delta_eta_WZ1, Delta_eta_WZ2], 
series_gt, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 8, 40], r"\Delta \eta(j_{0}, j_{1})")

# %% [markdown]
# ## Cutting on delta eta jj

# %%
DeltaEta_jj_cut = 4.0

Sig_Mask_1= (Delta_eta_S > DeltaEta_jj_cut)
S1_df_tau = S1_df_tau[Sig_Mask_1]; m_T_S=m_T_S[Sig_Mask_1]; m_jj_S=m_jj_S[Sig_Mask_1]; Delta_eta_S=Delta_eta_S[Sig_Mask_1]; Mul_eta_S=Mul_eta_S[Sig_Mask_1]

W_Mask_1=(Delta_eta_W > DeltaEta_jj_cut)
W_df_tau = W_df_tau[W_Mask_1]; m_T_W=m_T_W[W_Mask_1]; m_jj_W=m_jj_W[W_Mask_1]; Delta_eta_W=Delta_eta_W[W_Mask_1]; Mul_eta_W=Mul_eta_W[W_Mask_1]

TTbar_Mask_1=(Delta_eta_ttbar > DeltaEta_jj_cut)
TTbar_df_tau = TTbar_df_tau[TTbar_Mask_1]; m_T_ttbar=m_T_ttbar[TTbar_Mask_1]; m_jj_ttbar=m_jj_ttbar[TTbar_Mask_1]; Delta_eta_ttbar=Delta_eta_ttbar[TTbar_Mask_1]; Mul_eta_ttbar=Mul_eta_ttbar[TTbar_Mask_1]

WW_Mask_1=(Delta_eta_WW > DeltaEta_jj_cut)
WW_df_tau = WW_df_tau[WW_Mask_1]; m_T_WW=m_T_WW[WW_Mask_1]; m_jj_WW=m_jj_WW[WW_Mask_1]; Delta_eta_WW=Delta_eta_WW[WW_Mask_1]; Mul_eta_WW=Mul_eta_WW[WW_Mask_1]

WZ1_Mask_1=(Delta_eta_WZ1 > DeltaEta_jj_cut)
WZ1_df_tau = WZ1_df_tau[WZ1_Mask_1]; m_T_WZ1=m_T_WZ1[WZ1_Mask_1]; m_jj_WZ1=m_jj_WZ1[WZ1_Mask_1]; Delta_eta_WZ1=Delta_eta_WZ1[WZ1_Mask_1]; Mul_eta_WZ1=Mul_eta_WZ1[WZ1_Mask_1]

WZ2_Mask_1=(Delta_eta_WZ2 > DeltaEta_jj_cut)
WZ2_df_tau = WZ2_df_tau[WZ2_Mask_1]; m_T_WZ2=m_T_WZ2[WZ2_Mask_1]; m_jj_WZ2=m_jj_WZ2[WZ2_Mask_1]; Delta_eta_WZ2=Delta_eta_WZ2[WZ2_Mask_1]; Mul_eta_WZ2=Mul_eta_WZ2[WZ2_Mask_1]

S_3=S1_df_tau.shape[0]
W_3=W_df_tau.shape[0]
TTbar_3=TTbar_df_tau.shape[0]
WW_3=WW_df_tau.shape[0]
WZ1_3=WZ1_df_tau.shape[0]
WZ2_3=WZ2_df_tau.shape[0]

print(S_3,W_3,TTbar_3,WW_3,WZ1_3,WZ2_3)
# Out:
# 595 2891 1748 722 230 46

# %% [markdown]
# ## Wprime variables

# %%
plot_var([S1_df_tau, W_df_tau, TTbar_df_tau, WW_df_tau, WZ1_df_tau, WZ2_df_tau], "tau_pt0", 20, 1000, 30, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$p_{T}(\tau)$ [GeV]", size = 14)
plot_var([S1_df_tau, W_df_tau, TTbar_df_tau, WW_df_tau, WZ1_df_tau, WZ2_df_tau], "missinget_met", 20, 1000, 30, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$p_{T}^{miss}$ [GeV]", size = 14)
plot_var([S1_df_tau, W_df_tau, TTbar_df_tau, WW_df_tau, WZ1_df_tau, WZ2_df_tau], "Delta_phi_tau_Met", 0, 4, 20, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$|\Delta \phi(\tau, p_{T}^{miss})|$", size = 14)

# %%
S1_df_tau["taumet_ptratio"] = S1_df_tau["tau_pt0"]/S1_df_tau["missinget_met"]
W_df_tau["taumet_ptratio"] = W_df_tau["tau_pt0"]/W_df_tau["missinget_met"]
TTbar_df_tau["taumet_ptratio"] = TTbar_df_tau["tau_pt0"]/TTbar_df_tau["missinget_met"]
WW_df_tau["taumet_ptratio"] = WW_df_tau["tau_pt0"]/WW_df_tau["missinget_met"]
WZ1_df_tau["taumet_ptratio"] = WZ1_df_tau["tau_pt0"]/WZ1_df_tau["missinget_met"]
WZ2_df_tau["taumet_ptratio"] = WZ2_df_tau["tau_pt0"]/WZ2_df_tau["missinget_met"]

# %%
plot_var([S1_df_tau, W_df_tau, TTbar_df_tau, WW_df_tau, WZ1_df_tau, WZ2_df_tau], "taumet_ptratio", 0, 4, 40, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$p_{T}(\tau)/p_{T}^{miss}$", size = 14)

# %%
plot_significances(S1_df_tau, [W_df_tau, TTbar_df_tau, WW_df_tau, WZ1_df_tau, WZ2_df_tau], 
pt_tau, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [20, 1000, 30], r"p_{T}(\tau) [GeV]")

# %%
plot_significances(S1_df_tau, [W_df_tau, TTbar_df_tau, WW_df_tau, WZ1_df_tau, WZ2_df_tau], 
pt_miss, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [20, 1000, 30], r"p_T^{miss} [GeV]")
# Out:
# /cms/Jose/VBFWprime/PhenoWay/AnasWorld.py:286: RuntimeWarning: invalid value encountered in true_divide
#   sign1 = S/np.sqrt(S+TotB)

# %%
plot_significances(S1_df_tau, [W_df_tau, TTbar_df_tau, WW_df_tau, WZ1_df_tau, WZ2_df_tau], 
phi_tau_met, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 4, 20], r"\Delta \phi(\tau, p_{T}^{miss})")
# Out:
# /cms/Jose/VBFWprime/PhenoWay/AnasWorld.py:286: RuntimeWarning: invalid value encountered in true_divide
#   sign1 = S/np.sqrt(S+TotB)

# %%
plot_significances(S1_df_tau, [W_df_tau, TTbar_df_tau, WW_df_tau, WZ1_df_tau, WZ2_df_tau], 
taumet_ptratio, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 4, 40], r"p_{T}(\tau)/p_{T}^{miss}")

# %% [markdown]
# ## Cutting on the tau pT

# %%
taupT=150

Sig_Mask_1=S1_df_tau.tau_pt0 > taupT
S1_df_tau = S1_df_tau[Sig_Mask_1]; m_T_S=m_T_S[Sig_Mask_1]; m_jj_S=m_jj_S[Sig_Mask_1]; Delta_eta_S=Delta_eta_S[Sig_Mask_1]; Mul_eta_S=Mul_eta_S[Sig_Mask_1]

W_Mask_1=W_df_tau.tau_pt0 > taupT
W_df_tau = W_df_tau[W_Mask_1]; m_T_W=m_T_W[W_Mask_1]; m_jj_W=m_jj_W[W_Mask_1]; Delta_eta_W=Delta_eta_W[W_Mask_1]; Mul_eta_W=Mul_eta_W[W_Mask_1]

TTbar_Mask_1=TTbar_df_tau.tau_pt0 > taupT
TTbar_df_tau = TTbar_df_tau[TTbar_Mask_1]; m_T_ttbar=m_T_ttbar[TTbar_Mask_1]; m_jj_ttbar=m_jj_ttbar[TTbar_Mask_1]; Delta_eta_ttbar=Delta_eta_ttbar[TTbar_Mask_1]; Mul_eta_ttbar=Mul_eta_ttbar[TTbar_Mask_1]

WW_Mask_1=WW_df_tau.tau_pt0 > taupT
WW_df_tau = WW_df_tau[WW_Mask_1]; m_T_WW=m_T_WW[WW_Mask_1]; m_jj_WW=m_jj_WW[WW_Mask_1]; Delta_eta_WW=Delta_eta_WW[WW_Mask_1]; Mul_eta_WW=Mul_eta_WW[WW_Mask_1]

WZ1_Mask_1=WZ1_df_tau.tau_pt0 > taupT
WZ1_df_tau = WZ1_df_tau[WZ1_Mask_1]; m_T_WZ1=m_T_WZ1[WZ1_Mask_1]; m_jj_WZ1=m_jj_WZ1[WZ1_Mask_1]; Delta_eta_WZ1=Delta_eta_WZ1[WZ1_Mask_1]; Mul_eta_WZ1=Mul_eta_WZ1[WZ1_Mask_1]

WZ2_Mask_1=WZ2_df_tau.tau_pt0 > taupT
WZ2_df_tau = WZ2_df_tau[WZ2_Mask_1]; m_T_WZ2=m_T_WZ2[WZ2_Mask_1]; m_jj_WZ2=m_jj_WZ2[WZ2_Mask_1]; Delta_eta_WZ2=Delta_eta_WZ2[WZ2_Mask_1]; Mul_eta_WZ2=Mul_eta_WZ2[WZ2_Mask_1]

S_4=S1_df_tau.shape[0]
W_4=W_df_tau.shape[0]
TTbar_4=TTbar_df_tau.shape[0]
WW_4=WW_df_tau.shape[0]
WZ1_4=WZ1_df_tau.shape[0]
WZ2_4=WZ2_df_tau.shape[0]

print(S_4,W_4,TTbar_4,WW_4,WZ1_4,WZ2_4)
# Out:
# 485 435 467 108 40 6

# %%
plot_significances(S1_df_tau, [W_df_tau, TTbar_df_tau, WW_df_tau, WZ1_df_tau, WZ2_df_tau], 
pt_miss, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [20, 1000, 30], r"p_T^{miss}")
# Out:
# /cms/Jose/VBFWprime/PhenoWay/AnasWorld.py:286: RuntimeWarning: invalid value encountered in true_divide
#   sign1 = S/np.sqrt(S+TotB)

# %%
plot_significances(S1_df_tau, [W_df_tau, TTbar_df_tau, WW_df_tau, WZ1_df_tau, WZ2_df_tau], 
phi_tau_met, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 4, 20], r"\Delta \phi(\tau, p_{T}^{miss})")
# Out:
# /cms/Jose/VBFWprime/PhenoWay/AnasWorld.py:286: RuntimeWarning: invalid value encountered in true_divide
#   sign1 = S/np.sqrt(S+TotB)

# %%
plot_significances(S1_df_tau, [W_df_tau, TTbar_df_tau, WW_df_tau, WZ1_df_tau, WZ2_df_tau], 
taumet_ptratio, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 4, 40], r"p_{T}(\tau)/p_{T}^{miss}")

# %% [markdown]
# ## Cutting on MET

# %%
MET=50

Sig_Mask_1=S1_df_tau.missinget_met > MET
S1_df_tau = S1_df_tau[Sig_Mask_1]; m_T_S=m_T_S[Sig_Mask_1]; m_jj_S=m_jj_S[Sig_Mask_1]; Delta_eta_S=Delta_eta_S[Sig_Mask_1]; Mul_eta_S=Mul_eta_S[Sig_Mask_1]

W_Mask_1=W_df_tau.missinget_met > MET
W_df_tau = W_df_tau[W_Mask_1]; m_T_W=m_T_W[W_Mask_1]; m_jj_W=m_jj_W[W_Mask_1]; Delta_eta_W=Delta_eta_W[W_Mask_1]; Mul_eta_W=Mul_eta_W[W_Mask_1]

TTbar_Mask_1=TTbar_df_tau.missinget_met > MET
TTbar_df_tau = TTbar_df_tau[TTbar_Mask_1]; m_T_ttbar=m_T_ttbar[TTbar_Mask_1]; m_jj_ttbar=m_jj_ttbar[TTbar_Mask_1]; Delta_eta_ttbar=Delta_eta_ttbar[TTbar_Mask_1]; Mul_eta_ttbar=Mul_eta_ttbar[TTbar_Mask_1]

WW_Mask_1=WW_df_tau.missinget_met > MET
WW_df_tau = WW_df_tau[WW_Mask_1]; m_T_WW=m_T_WW[WW_Mask_1]; m_jj_WW=m_jj_WW[WW_Mask_1]; Delta_eta_WW=Delta_eta_WW[WW_Mask_1]; Mul_eta_WW=Mul_eta_WW[WW_Mask_1]

WZ1_Mask_1=WZ1_df_tau.missinget_met > MET
WZ1_df_tau = WZ1_df_tau[WZ1_Mask_1]; m_T_WZ1=m_T_WZ1[WZ1_Mask_1]; m_jj_WZ1=m_jj_WZ1[WZ1_Mask_1]; Delta_eta_WZ1=Delta_eta_WZ1[WZ1_Mask_1]; Mul_eta_WZ1=Mul_eta_WZ1[WZ1_Mask_1]

WZ2_Mask_1=WZ2_df_tau.missinget_met > MET
WZ2_df_tau = WZ2_df_tau[WZ2_Mask_1]; m_T_WZ2=m_T_WZ2[WZ2_Mask_1]; m_jj_WZ2=m_jj_WZ2[WZ2_Mask_1]; Delta_eta_WZ2=Delta_eta_WZ2[WZ2_Mask_1]; Mul_eta_WZ2=Mul_eta_WZ2[WZ2_Mask_1]

S_5=S1_df_tau.shape[0]
W_5=W_df_tau.shape[0]
TTbar_5=TTbar_df_tau.shape[0]
WW_5=WW_df_tau.shape[0]
WZ1_5=WZ1_df_tau.shape[0]
WZ2_5=WZ2_df_tau.shape[0]

print(S_5,W_5,TTbar_5,WW_5,WZ1_5,WZ2_5)
# Out:
# 485 435 467 108 40 6

# %%
plot_var([S1_df_tau, W_df_tau, TTbar_df_tau, WW_df_tau, WZ1_df_tau, WZ2_df_tau], "Delta_phi_tau_Met", 0, 4, 20, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$|\Delta \phi(\tau, p_{T}^{miss})|$", size = 14)

# %%
plot_significances(S1_df_tau, [W_df_tau, TTbar_df_tau, WW_df_tau, WZ1_df_tau, WZ2_df_tau], 
phi_tau_met, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 4, 20], r"\Delta \phi(\tau, p_{T}^{miss})")
# Out:
# /cms/Jose/VBFWprime/PhenoWay/AnasWorld.py:286: RuntimeWarning: invalid value encountered in true_divide
#   sign1 = S/np.sqrt(S+TotB)

# %% [markdown]
# ## Cutting on Delta phi mu met

# %%
DeltaPhitauMet=1.5

Sig_Mask_1=S1_df_tau.Delta_phi_tau_Met > DeltaPhitauMet
S1_df_tau = S1_df_tau[Sig_Mask_1]; m_T_S=m_T_S[Sig_Mask_1]; m_jj_S=m_jj_S[Sig_Mask_1]; Delta_eta_S=Delta_eta_S[Sig_Mask_1]; Mul_eta_S=Mul_eta_S[Sig_Mask_1]

W_Mask_1=W_df_tau.Delta_phi_tau_Met > DeltaPhitauMet
W_df_tau = W_df_tau[W_Mask_1]; m_T_W=m_T_W[W_Mask_1]; m_jj_W=m_jj_W[W_Mask_1]; Delta_eta_W=Delta_eta_W[W_Mask_1]; Mul_eta_W=Mul_eta_W[W_Mask_1]

TTbar_Mask_1=TTbar_df_tau.Delta_phi_tau_Met > DeltaPhitauMet
TTbar_df_tau = TTbar_df_tau[TTbar_Mask_1]; m_T_ttbar=m_T_ttbar[TTbar_Mask_1]; m_jj_ttbar=m_jj_ttbar[TTbar_Mask_1]; Delta_eta_ttbar=Delta_eta_ttbar[TTbar_Mask_1]; Mul_eta_ttbar=Mul_eta_ttbar[TTbar_Mask_1]

WW_Mask_1=WW_df_tau.Delta_phi_tau_Met > DeltaPhitauMet
WW_df_tau = WW_df_tau[WW_Mask_1]; m_T_WW=m_T_WW[WW_Mask_1]; m_jj_WW=m_jj_WW[WW_Mask_1]; Delta_eta_WW=Delta_eta_WW[WW_Mask_1]; Mul_eta_WW=Mul_eta_WW[WW_Mask_1]

WZ1_Mask_1=WZ1_df_tau.Delta_phi_tau_Met > DeltaPhitauMet
WZ1_df_tau = WZ1_df_tau[WZ1_Mask_1]; m_T_WZ1=m_T_WZ1[WZ1_Mask_1]; m_jj_WZ1=m_jj_WZ1[WZ1_Mask_1]; Delta_eta_WZ1=Delta_eta_WZ1[WZ1_Mask_1]; Mul_eta_WZ1=Mul_eta_WZ1[WZ1_Mask_1]

WZ2_Mask_1=WZ2_df_tau.Delta_phi_tau_Met > DeltaPhitauMet
WZ2_df_tau = WZ2_df_tau[WZ2_Mask_1]; m_T_WZ2=m_T_WZ2[WZ2_Mask_1]; m_jj_WZ2=m_jj_WZ2[WZ2_Mask_1]; Delta_eta_WZ2=Delta_eta_WZ2[WZ2_Mask_1]; Mul_eta_WZ2=Mul_eta_WZ2[WZ2_Mask_1]

S_6=S1_df_tau.shape[0]
W_6=W_df_tau.shape[0]
TTbar_6=TTbar_df_tau.shape[0]
WW_6=WW_df_tau.shape[0]
WZ1_6=WZ1_df_tau.shape[0]
WZ2_6=WZ2_df_tau.shape[0]

print(S_6,W_6,TTbar_6,WW_6,WZ1_6,WZ2_6)
# Out:
# 456 180 200 27 22 2

# %% [markdown]
# ## Final Significance and efficiencies

# %%
AllCuts=[
    np.array([S_0,W_0,TTbar_0,WW_0,WZ1_0,WZ2_0])*np.array([W_S, W_W, W_TTbar, W_WW, W_WZ1, W_WZ2]),
    np.array([S_1,W_1,TTbar_1,WW_1,WZ1_1,WZ2_1])*np.array([W_S, W_W, W_TTbar, W_WW, W_WZ1, W_WZ2]),
    np.array([S_2,W_2,TTbar_2,WW_2,WZ1_2,WZ2_2])*np.array([W_S, W_W, W_TTbar, W_WW, W_WZ1, W_WZ2]),
    np.array([S_3,W_3,TTbar_3,WW_3,WZ1_3,WZ2_3])*np.array([W_S, W_W, W_TTbar, W_WW, W_WZ1, W_WZ2]),
    np.array([S_4,W_4,TTbar_4,WW_4,WZ1_4,WZ2_4])*np.array([W_S, W_W, W_TTbar, W_WW, W_WZ1, W_WZ2]),
    np.array([S_5,W_5,TTbar_5,WW_5,WZ1_5,WZ2_5])*np.array([W_S, W_W, W_TTbar, W_WW, W_WZ1, W_WZ2]),
    np.array([S_6,W_6,TTbar_6,WW_6,WZ1_6,WZ2_6])*np.array([W_S, W_W, W_TTbar, W_WW, W_WZ1, W_WZ2])
]

# %%
PrintSign(AllCuts)
# Out:
# S/sqrt(S+B)
# Cut 1 1.8358732619415659
# Cut 2 2.0484733151807424
# Cut 3 2.925221168776193
# Cut 4 5.194035895887845
# Cut 5 8.232655046093031
# Cut 6 8.232655046093031
# Cut 7 9.522789605899213

# %%
EfficiencyTables(AllCuts)
# Out:
# N-1 efficiencies:
# Cut 1 [71.32 44.52 30.41 33.7  45.35 32.8 ]
# Cut 2 [62.03 19.66 13.17 14.33 19.43 15.07]
# Cut 3 [86.11 21.07 19.48 17.59 20.74 18.47]
# Cut 4 [81.51 15.05 26.72 14.96 17.39 13.04]
# Cut 5 [100. 100. 100. 100. 100. 100.]
# Cut 6 [94.02 41.38 42.83 25.   55.   33.33]
# Cumulative efficiencies:
# Cut 1 [71.32 44.52 30.41 33.7  45.35 32.8 ]
# Cut 2 [44.24  8.75  4.    4.83  8.81  4.94]
# Cut 3 [38.09  1.84  0.78  0.85  1.83  0.91]
# Cut 4 [31.05  0.28  0.21  0.13  0.32  0.12]
# Cut 5 [31.05  0.28  0.21  0.13  0.32  0.12]
# Cut 6 [29.19  0.11  0.09  0.03  0.17  0.04]

# %%
plot_ser([m_T_S, m_T_W, m_T_ttbar, m_T_WW, m_T_WZ1, m_T_WZ2], 0, 3000, 15, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$m_{T}$ [GeV]", size = 14)
