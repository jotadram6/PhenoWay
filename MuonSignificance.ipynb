# %%
from AnasWorld import *

# %% [markdown]
# # Muon Channel

# %%
Z1_M1000_df = pd.read_csv("../Wprime_VBF_gWWpZ1.csv")
Bkg_W_df = pd.read_csv("../Wbkg_15032022.csv")
Bkg_ttbar_df = pd.read_csv("../TTbarbkg_15032022.csv")
Bkg_WW_df = pd.read_csv("../WWbkg_28032022.csv")
Bkg_WZ1_df = pd.read_csv("../WZ1_15032022.csv")
Bkg_WZ2_df = pd.read_csv("../WZ2_15032022.csv")

# %%
S_I=Z1_M1000_df.shape[0]
W_I=Bkg_W_df.shape[0]
TTbar_I=Bkg_ttbar_df.shape[0]
WW_I=Bkg_WW_df.shape[0]
WZ1_I=Bkg_WZ1_df.shape[0]
WZ2_I=Bkg_WZ2_df.shape[0]

print(S_I,W_I,TTbar_I,WW_I,WZ1_I,WZ2_I)
# Out:
# 50000 2200000 1100000 2100000 100000 100000

# %%
S1_df_mu = basic_allch_cuts(Z1_M1000_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 0, n_mu = 1, pt_mu = 25)
m_T_S, m_jj_S, Delta_eta_S, Mul_eta_S = muVBFvars(S1_df_mu)
W_df_mu = basic_allch_cuts(Bkg_W_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 0, n_mu = 1, pt_mu = 25)
m_T_W, m_jj_W, Delta_eta_W, Mul_eta_W = muVBFvars(W_df_mu)
TTbar_df_mu = basic_allch_cuts(Bkg_ttbar_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 0, n_mu = 1, pt_mu = 25)
m_T_ttbar, m_jj_ttbar, Delta_eta_ttbar, Mul_eta_ttbar = muVBFvars(TTbar_df_mu)
WW_df_mu = basic_allch_cuts(Bkg_WW_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 0, n_mu = 1, pt_mu = 25)
m_T_WW, m_jj_WW, Delta_eta_WW, Mul_eta_WW = muVBFvars(WW_df_mu)
WZ1_df_mu = basic_allch_cuts(Bkg_WZ1_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 0, n_mu = 1, pt_mu = 25)
m_T_WZ1, m_jj_WZ1, Delta_eta_WZ1, Mul_eta_WZ1 = muVBFvars(WZ1_df_mu)
WZ2_df_mu = basic_allch_cuts(Bkg_WZ2_df, n_j = 2, pt_j = 60, n_b = 0, met = 50, n_tau = 0, n_e = 0, n_mu = 1, pt_mu = 25)
m_T_WZ2, m_jj_WZ2, Delta_eta_WZ2, Mul_eta_WZ2 = muVBFvars(WZ2_df_mu)

# %%
S_0=S1_df_mu.shape[0]
W_0=W_df_mu.shape[0]
TTbar_0=TTbar_df_mu.shape[0]
WW_0=WW_df_mu.shape[0]
WZ1_0=WZ1_df_mu.shape[0]
WZ2_0=WZ2_df_mu.shape[0]

print(S_0,W_0,TTbar_0,WW_0,WZ1_0,WZ2_0)
# Out:
# 4198 348366 211229 147713 8487 20001

# %%
#Cross sections in pb
S_xs = 0.1
W_xs = 6.406
TTbar_xs = 1.675
WW_xs = 0.05653
WZ1_xs = 0.001198
WZ2_xs = 0.04195

#Lumi 
lumi=150000

#Weights
W_S = S_xs*lumi/Z1_M1000_df.shape[0]
W_W = W_xs*lumi/Bkg_W_df.shape[0]
W_TTbar = TTbar_xs*lumi/Bkg_ttbar_df.shape[0]
W_WW = WW_xs*lumi/Bkg_WW_df.shape[0]
W_WZ1 = WZ1_xs*lumi/Bkg_WZ1_df.shape[0]
W_WZ2 = WZ2_xs*lumi/Bkg_WZ2_df.shape[0]

# %% [markdown]
# ## VBF variables

# %%
plot_ser([Mul_eta_S, Mul_eta_W, Mul_eta_ttbar, Mul_eta_WW, Mul_eta_WZ1, Mul_eta_WZ2], -20, 20, 60, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$\eta(j_{1})\eta(j_{2})$ [GeV]", size = 14)
plot_ser([Delta_eta_S, Delta_eta_W, Delta_eta_ttbar, Delta_eta_WW, Delta_eta_WZ1, Delta_eta_WZ2], 0, 10, 40, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$\Delta \eta(j_{0}, j_{1})$ ", size = 14)
plot_ser([m_jj_S, m_jj_W, m_jj_ttbar, m_jj_WW, m_jj_WZ1, m_jj_WZ2], 0, 5000, 50, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$m(j_{0}, j_{1})$ ", size = 14)

# %%
plot_significances(m_jj_S, [m_jj_W, m_jj_ttbar, m_jj_WW, m_jj_WZ1, m_jj_WZ2], 
series_gt, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 5000, 50], r"m(j_{0}, j_{1}) [GeV]")

# %%
plot_significances(Delta_eta_S, [Delta_eta_W, Delta_eta_ttbar, Delta_eta_WW, Delta_eta_WZ1, Delta_eta_WZ2], 
series_gt, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 10, 40], r"\Delta \eta(j_{0}, j_{1})")
# Out:
# /cms/Jose/VBFWprime/PhenoWay/AnasWorld.py:286: RuntimeWarning: invalid value encountered in true_divide
#   sign1 = S/np.sqrt(S+TotB)

# %% [markdown]
# ## Selecting events with jets in opposite hemispheres

# %%
Sig_Mask_1=Mul_eta_S < 0
S1_df_mu = S1_df_mu[Sig_Mask_1]; m_T_S=m_T_S[Sig_Mask_1]; m_jj_S=m_jj_S[Sig_Mask_1]; Delta_eta_S=Delta_eta_S[Sig_Mask_1]; Mul_eta_S=Mul_eta_S[Sig_Mask_1]

W_Mask_1=Mul_eta_W < 0
W_df_mu = W_df_mu[W_Mask_1]; m_T_W=m_T_W[W_Mask_1]; m_jj_W=m_jj_W[W_Mask_1]; Delta_eta_W=Delta_eta_W[W_Mask_1]; Mul_eta_W=Mul_eta_W[W_Mask_1]

TTbar_Mask_1=Mul_eta_ttbar < 0
TTbar_df_mu = TTbar_df_mu[TTbar_Mask_1]; m_T_ttbar=m_T_ttbar[TTbar_Mask_1]; m_jj_ttbar=m_jj_ttbar[TTbar_Mask_1]; Delta_eta_ttbar=Delta_eta_ttbar[TTbar_Mask_1]; Mul_eta_ttbar=Mul_eta_ttbar[TTbar_Mask_1]

WW_Mask_1=Mul_eta_WW < 0
WW_df_mu = WW_df_mu[WW_Mask_1]; m_T_WW=m_T_WW[WW_Mask_1]; m_jj_WW=m_jj_WW[WW_Mask_1]; Delta_eta_WW=Delta_eta_WW[WW_Mask_1]; Mul_eta_WW=Mul_eta_WW[WW_Mask_1]

WZ1_Mask_1=Mul_eta_WZ1 < 0
WZ1_df_mu = WZ1_df_mu[WZ1_Mask_1]; m_T_WZ1=m_T_WZ1[WZ1_Mask_1]; m_jj_WZ1=m_jj_WZ1[WZ1_Mask_1]; Delta_eta_WZ1=Delta_eta_WZ1[WZ1_Mask_1]; Mul_eta_WZ1=Mul_eta_WZ1[WZ1_Mask_1]

WZ2_Mask_1=Mul_eta_WZ2 < 0
WZ2_df_mu = WZ2_df_mu[WZ2_Mask_1]; m_T_WZ2=m_T_WZ2[WZ2_Mask_1]; m_jj_WZ2=m_jj_WZ2[WZ2_Mask_1]; Delta_eta_WZ2=Delta_eta_WZ2[WZ2_Mask_1]; Mul_eta_WZ2=Mul_eta_WZ2[WZ2_Mask_1]

S_1=S1_df_mu.shape[0]
W_1=W_df_mu.shape[0]
TTbar_1=TTbar_df_mu.shape[0]
WW_1=WW_df_mu.shape[0]
WZ1_1=WZ1_df_mu.shape[0]
WZ2_1=WZ2_df_mu.shape[0]

print(S_1,W_1,TTbar_1,WW_1,WZ1_1,WZ2_1)
# Out:
# 3101 156787 62890 48458 2711 9339

# %%
plot_significances(m_jj_S, [m_jj_W, m_jj_ttbar, m_jj_WW, m_jj_WZ1, m_jj_WZ2], 
series_gt, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 5000, 25], r"m(j_{0}, j_{1}) [GeV]")

# %%
plot_significances(Delta_eta_S, [Delta_eta_W, Delta_eta_ttbar, Delta_eta_WW, Delta_eta_WZ1, Delta_eta_WZ2], 
series_gt, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 8, 40], r"\Delta \eta(j_{0}, j_{1})")

# %% [markdown]
# ## Selecting events on mjj

# %%
m_jj_cut = 1000

Sig_Mask_1= (m_jj_S > m_jj_cut)
S1_df_mu = S1_df_mu[Sig_Mask_1]; m_T_S=m_T_S[Sig_Mask_1]; m_jj_S=m_jj_S[Sig_Mask_1]; Delta_eta_S=Delta_eta_S[Sig_Mask_1]; Mul_eta_S=Mul_eta_S[Sig_Mask_1]

W_Mask_1=(m_jj_W > m_jj_cut)
W_df_mu = W_df_mu[W_Mask_1]; m_T_W=m_T_W[W_Mask_1]; m_jj_W=m_jj_W[W_Mask_1]; Delta_eta_W=Delta_eta_W[W_Mask_1]; Mul_eta_W=Mul_eta_W[W_Mask_1]

TTbar_Mask_1=(m_jj_ttbar > m_jj_cut)
TTbar_df_mu = TTbar_df_mu[TTbar_Mask_1]; m_T_ttbar=m_T_ttbar[TTbar_Mask_1]; m_jj_ttbar=m_jj_ttbar[TTbar_Mask_1]; Delta_eta_ttbar=Delta_eta_ttbar[TTbar_Mask_1]; Mul_eta_ttbar=Mul_eta_ttbar[TTbar_Mask_1]

WW_Mask_1=(m_jj_WW > m_jj_cut)
WW_df_mu = WW_df_mu[WW_Mask_1]; m_T_WW=m_T_WW[WW_Mask_1]; m_jj_WW=m_jj_WW[WW_Mask_1]; Delta_eta_WW=Delta_eta_WW[WW_Mask_1]; Mul_eta_WW=Mul_eta_WW[WW_Mask_1]

WZ1_Mask_1=(m_jj_WZ1 > m_jj_cut)
WZ1_df_mu = WZ1_df_mu[WZ1_Mask_1]; m_T_WZ1=m_T_WZ1[WZ1_Mask_1]; m_jj_WZ1=m_jj_WZ1[WZ1_Mask_1]; Delta_eta_WZ1=Delta_eta_WZ1[WZ1_Mask_1]; Mul_eta_WZ1=Mul_eta_WZ1[WZ1_Mask_1]

WZ2_Mask_1=(m_jj_WZ2 > m_jj_cut)
WZ2_df_mu = WZ2_df_mu[WZ2_Mask_1]; m_T_WZ2=m_T_WZ2[WZ2_Mask_1]; m_jj_WZ2=m_jj_WZ2[WZ2_Mask_1]; Delta_eta_WZ2=Delta_eta_WZ2[WZ2_Mask_1]; Mul_eta_WZ2=Mul_eta_WZ2[WZ2_Mask_1]

S_2=S1_df_mu.shape[0]
W_2=W_df_mu.shape[0]
TTbar_2=TTbar_df_mu.shape[0]
WW_2=WW_df_mu.shape[0]
WZ1_2=WZ1_df_mu.shape[0]
WZ2_2=WZ2_df_mu.shape[0]

print(S_2,W_2,TTbar_2,WW_2,WZ1_2,WZ2_2)
# Out:
# 1979 30821 7867 6948 386 1892

# %%
plot_significances(Delta_eta_S, [Delta_eta_W, Delta_eta_ttbar, Delta_eta_WW, Delta_eta_WZ1, Delta_eta_WZ2], 
series_gt, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 8, 40], r"\Delta \eta(j_{0}, j_{1})")

# %% [markdown]
# ## Cutting on delta eta jj

# %%
DeltaEta_jj_cut = 4.0

Sig_Mask_1= (Delta_eta_S > DeltaEta_jj_cut)
S1_df_mu = S1_df_mu[Sig_Mask_1]; m_T_S=m_T_S[Sig_Mask_1]; m_jj_S=m_jj_S[Sig_Mask_1]; Delta_eta_S=Delta_eta_S[Sig_Mask_1]; Mul_eta_S=Mul_eta_S[Sig_Mask_1]

W_Mask_1=(Delta_eta_W > DeltaEta_jj_cut)
W_df_mu = W_df_mu[W_Mask_1]; m_T_W=m_T_W[W_Mask_1]; m_jj_W=m_jj_W[W_Mask_1]; Delta_eta_W=Delta_eta_W[W_Mask_1]; Mul_eta_W=Mul_eta_W[W_Mask_1]

TTbar_Mask_1=(Delta_eta_ttbar > DeltaEta_jj_cut)
TTbar_df_mu = TTbar_df_mu[TTbar_Mask_1]; m_T_ttbar=m_T_ttbar[TTbar_Mask_1]; m_jj_ttbar=m_jj_ttbar[TTbar_Mask_1]; Delta_eta_ttbar=Delta_eta_ttbar[TTbar_Mask_1]; Mul_eta_ttbar=Mul_eta_ttbar[TTbar_Mask_1]

WW_Mask_1=(Delta_eta_WW > DeltaEta_jj_cut)
WW_df_mu = WW_df_mu[WW_Mask_1]; m_T_WW=m_T_WW[WW_Mask_1]; m_jj_WW=m_jj_WW[WW_Mask_1]; Delta_eta_WW=Delta_eta_WW[WW_Mask_1]; Mul_eta_WW=Mul_eta_WW[WW_Mask_1]

WZ1_Mask_1=(Delta_eta_WZ1 > DeltaEta_jj_cut)
WZ1_df_mu = WZ1_df_mu[WZ1_Mask_1]; m_T_WZ1=m_T_WZ1[WZ1_Mask_1]; m_jj_WZ1=m_jj_WZ1[WZ1_Mask_1]; Delta_eta_WZ1=Delta_eta_WZ1[WZ1_Mask_1]; Mul_eta_WZ1=Mul_eta_WZ1[WZ1_Mask_1]

WZ2_Mask_1=(Delta_eta_WZ2 > DeltaEta_jj_cut)
WZ2_df_mu = WZ2_df_mu[WZ2_Mask_1]; m_T_WZ2=m_T_WZ2[WZ2_Mask_1]; m_jj_WZ2=m_jj_WZ2[WZ2_Mask_1]; Delta_eta_WZ2=Delta_eta_WZ2[WZ2_Mask_1]; Mul_eta_WZ2=Mul_eta_WZ2[WZ2_Mask_1]

S_3=S1_df_mu.shape[0]
W_3=W_df_mu.shape[0]
TTbar_3=TTbar_df_mu.shape[0]
WW_3=WW_df_mu.shape[0]
WZ1_3=WZ1_df_mu.shape[0]
WZ2_3=WZ2_df_mu.shape[0]

print(S_3,W_3,TTbar_3,WW_3,WZ1_3,WZ2_3)
# Out:
# 1757 6346 1598 1289 82 358

# %% [markdown]
# ## Wprime variables

# %%
plot_var([S1_df_mu, W_df_mu, TTbar_df_mu, WW_df_mu, WZ1_df_mu, WZ2_df_mu], "muon_pt0", 20, 1000, 30, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$p_{T}(\mu)$ [GeV]", size = 14)
plot_var([S1_df_mu, W_df_mu, TTbar_df_mu, WW_df_mu, WZ1_df_mu, WZ2_df_mu], "missinget_met", 20, 1000, 30, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$p_{T}^{miss}$ [GeV]", size = 14)
plot_var([S1_df_mu, W_df_mu, TTbar_df_mu, WW_df_mu, WZ1_df_mu, WZ2_df_mu], "Delta_phi_mu_Met", 0, 4, 20, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$|\Delta \phi(\mu, p_{T}^{miss})|$", size = 14)

# %%
S1_df_mu["mumet_ptratio"] = S1_df_mu["muon_pt0"]/S1_df_mu["missinget_met"]
W_df_mu["mumet_ptratio"] = W_df_mu["muon_pt0"]/W_df_mu["missinget_met"]
TTbar_df_mu["mumet_ptratio"] = TTbar_df_mu["muon_pt0"]/TTbar_df_mu["missinget_met"]
WW_df_mu["mumet_ptratio"] = WW_df_mu["muon_pt0"]/WW_df_mu["missinget_met"]
WZ1_df_mu["mumet_ptratio"] = WZ1_df_mu["muon_pt0"]/WZ1_df_mu["missinget_met"]
WZ2_df_mu["mumet_ptratio"] = WZ2_df_mu["muon_pt0"]/WZ2_df_mu["missinget_met"]

# %%
plot_var([S1_df_mu, W_df_mu, TTbar_df_mu, WW_df_mu, WZ1_df_mu, WZ2_df_mu], "mumet_ptratio", 0, 4, 40, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$p_{T}(\mu)/p_{T}^{miss}$", size = 14)

# %%
plot_significances(S1_df_mu, [W_df_mu, TTbar_df_mu, WW_df_mu, WZ1_df_mu, WZ2_df_mu], 
pt_mu, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [20, 1000, 30], r"p_T(\mu)")

# %%
plot_significances(S1_df_mu, [W_df_mu, TTbar_df_mu, WW_df_mu, WZ1_df_mu, WZ2_df_mu], 
pt_miss, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [20, 1000, 30], r"p_T^{miss}")

# %%
plot_significances(S1_df_mu, [W_df_mu, TTbar_df_mu, WW_df_mu, WZ1_df_mu, WZ2_df_mu], 
phi_mu_met, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 4, 20], r"\Delta \phi(\mu, p_{T}^{miss})")
# Out:
# /cms/Jose/VBFWprime/PhenoWay/AnasWorld.py:290: RuntimeWarning: invalid value encountered in true_divide
#   sign1 = S/np.sqrt(S+TotB)

# %%
plot_significances(S1_df_mu, [W_df_mu, TTbar_df_mu, WW_df_mu, WZ1_df_mu, WZ2_df_mu], 
mumet_ptratio, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 4, 40], r"p_{T}(\mu)/p_{T}^{miss}")

# %% [markdown]
# ## Cutting on the muon pT

# %%
MupT=200

Sig_Mask_1=S1_df_mu.muon_pt0 > MupT
S1_df_mu = S1_df_mu[Sig_Mask_1]; m_T_S=m_T_S[Sig_Mask_1]; m_jj_S=m_jj_S[Sig_Mask_1]; Delta_eta_S=Delta_eta_S[Sig_Mask_1]; Mul_eta_S=Mul_eta_S[Sig_Mask_1]

W_Mask_1=W_df_mu.muon_pt0 > MupT
W_df_mu = W_df_mu[W_Mask_1]; m_T_W=m_T_W[W_Mask_1]; m_jj_W=m_jj_W[W_Mask_1]; Delta_eta_W=Delta_eta_W[W_Mask_1]; Mul_eta_W=Mul_eta_W[W_Mask_1]

TTbar_Mask_1=TTbar_df_mu.muon_pt0 > MupT
TTbar_df_mu = TTbar_df_mu[TTbar_Mask_1]; m_T_ttbar=m_T_ttbar[TTbar_Mask_1]; m_jj_ttbar=m_jj_ttbar[TTbar_Mask_1]; Delta_eta_ttbar=Delta_eta_ttbar[TTbar_Mask_1]; Mul_eta_ttbar=Mul_eta_ttbar[TTbar_Mask_1]

WW_Mask_1=WW_df_mu.muon_pt0 > MupT
WW_df_mu = WW_df_mu[WW_Mask_1]; m_T_WW=m_T_WW[WW_Mask_1]; m_jj_WW=m_jj_WW[WW_Mask_1]; Delta_eta_WW=Delta_eta_WW[WW_Mask_1]; Mul_eta_WW=Mul_eta_WW[WW_Mask_1]

WZ1_Mask_1=WZ1_df_mu.muon_pt0 > MupT
WZ1_df_mu = WZ1_df_mu[WZ1_Mask_1]; m_T_WZ1=m_T_WZ1[WZ1_Mask_1]; m_jj_WZ1=m_jj_WZ1[WZ1_Mask_1]; Delta_eta_WZ1=Delta_eta_WZ1[WZ1_Mask_1]; Mul_eta_WZ1=Mul_eta_WZ1[WZ1_Mask_1]

WZ2_Mask_1=WZ2_df_mu.muon_pt0 > MupT
WZ2_df_mu = WZ2_df_mu[WZ2_Mask_1]; m_T_WZ2=m_T_WZ2[WZ2_Mask_1]; m_jj_WZ2=m_jj_WZ2[WZ2_Mask_1]; Delta_eta_WZ2=Delta_eta_WZ2[WZ2_Mask_1]; Mul_eta_WZ2=Mul_eta_WZ2[WZ2_Mask_1]

S_4=S1_df_mu.shape[0]
W_4=W_df_mu.shape[0]
TTbar_4=TTbar_df_mu.shape[0]
WW_4=WW_df_mu.shape[0]
WZ1_4=WZ1_df_mu.shape[0]
WZ2_4=WZ2_df_mu.shape[0]

print(S_4,W_4,TTbar_4,WW_4,WZ1_4,WZ2_4)
# Out:
# 1580 271 77 77 7 28

# %%
plot_significances(S1_df_mu, [W_df_mu, TTbar_df_mu, WW_df_mu, WZ1_df_mu, WZ2_df_mu], 
pt_miss, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [20, 1000, 30], r"p_T^{miss}")

# %%
plot_significances(S1_df_mu, [W_df_mu, TTbar_df_mu, WW_df_mu, WZ1_df_mu, WZ2_df_mu], 
phi_mu_met, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 4, 20], r"\Delta \phi(\mu, p_{T}^{miss})")
# Out:
# /cms/Jose/VBFWprime/PhenoWay/AnasWorld.py:286: RuntimeWarning: invalid value encountered in true_divide
#   sign1 = S/np.sqrt(S+TotB)

# %%
plot_significances(S1_df_mu, [W_df_mu, TTbar_df_mu, WW_df_mu, WZ1_df_mu, WZ2_df_mu], 
mumet_ptratio, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 4, 40], r"p_{T}(\mu)/p_{T}^{miss}")

# %% [markdown]
# ## Cutting on MET

# %%
MET=200

Sig_Mask_1=S1_df_mu.missinget_met > MET
S1_df_mu = S1_df_mu[Sig_Mask_1]; m_T_S=m_T_S[Sig_Mask_1]; m_jj_S=m_jj_S[Sig_Mask_1]; Delta_eta_S=Delta_eta_S[Sig_Mask_1]; Mul_eta_S=Mul_eta_S[Sig_Mask_1]

W_Mask_1=W_df_mu.missinget_met > MET
W_df_mu = W_df_mu[W_Mask_1]; m_T_W=m_T_W[W_Mask_1]; m_jj_W=m_jj_W[W_Mask_1]; Delta_eta_W=Delta_eta_W[W_Mask_1]; Mul_eta_W=Mul_eta_W[W_Mask_1]

TTbar_Mask_1=TTbar_df_mu.missinget_met > MET
TTbar_df_mu = TTbar_df_mu[TTbar_Mask_1]; m_T_ttbar=m_T_ttbar[TTbar_Mask_1]; m_jj_ttbar=m_jj_ttbar[TTbar_Mask_1]; Delta_eta_ttbar=Delta_eta_ttbar[TTbar_Mask_1]; Mul_eta_ttbar=Mul_eta_ttbar[TTbar_Mask_1]

WW_Mask_1=WW_df_mu.missinget_met > MET
WW_df_mu = WW_df_mu[WW_Mask_1]; m_T_WW=m_T_WW[WW_Mask_1]; m_jj_WW=m_jj_WW[WW_Mask_1]; Delta_eta_WW=Delta_eta_WW[WW_Mask_1]; Mul_eta_WW=Mul_eta_WW[WW_Mask_1]

WZ1_Mask_1=WZ1_df_mu.missinget_met > MET
WZ1_df_mu = WZ1_df_mu[WZ1_Mask_1]; m_T_WZ1=m_T_WZ1[WZ1_Mask_1]; m_jj_WZ1=m_jj_WZ1[WZ1_Mask_1]; Delta_eta_WZ1=Delta_eta_WZ1[WZ1_Mask_1]; Mul_eta_WZ1=Mul_eta_WZ1[WZ1_Mask_1]

WZ2_Mask_1=WZ2_df_mu.missinget_met > MET
WZ2_df_mu = WZ2_df_mu[WZ2_Mask_1]; m_T_WZ2=m_T_WZ2[WZ2_Mask_1]; m_jj_WZ2=m_jj_WZ2[WZ2_Mask_1]; Delta_eta_WZ2=Delta_eta_WZ2[WZ2_Mask_1]; Mul_eta_WZ2=Mul_eta_WZ2[WZ2_Mask_1]

S_5=S1_df_mu.shape[0]
W_5=W_df_mu.shape[0]
TTbar_5=TTbar_df_mu.shape[0]
WW_5=WW_df_mu.shape[0]
WZ1_5=WZ1_df_mu.shape[0]
WZ2_5=WZ2_df_mu.shape[0]

print(S_5,W_5,TTbar_5,WW_5,WZ1_5,WZ2_5)
# Out:
# 1533 210 51 57 5 26

# %%
plot_var([S1_df_mu, W_df_mu, TTbar_df_mu, WW_df_mu, WZ1_df_mu, WZ2_df_mu], "Delta_phi_mu_Met", 0, 4, 20, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$|\Delta \phi(\mu, p_{T}^{miss})|$", size = 14)

# %%
plot_significances(S1_df_mu, [W_df_mu, TTbar_df_mu, WW_df_mu, WZ1_df_mu, WZ2_df_mu], 
phi_mu_met, W_S, [W_W, W_TTbar, W_WW, W_WZ1, W_WZ2], [0, 7, 70], r"\Delta \phi(\mu, p_{T}^{miss})")
# Out:
# /cms/Jose/VBFWprime/PhenoWay/AnasWorld.py:286: RuntimeWarning: invalid value encountered in true_divide
#   sign1 = S/np.sqrt(S+TotB)

# %% [markdown]
# ## Cutting on Delta phi mu met

# %%
DeltaPhiMuMet=1.0

Sig_Mask_1=S1_df_mu.Delta_phi_mu_Met > DeltaPhiMuMet
S1_df_mu = S1_df_mu[Sig_Mask_1]; m_T_S=m_T_S[Sig_Mask_1]; m_jj_S=m_jj_S[Sig_Mask_1]; Delta_eta_S=Delta_eta_S[Sig_Mask_1]; Mul_eta_S=Mul_eta_S[Sig_Mask_1]

W_Mask_1=W_df_mu.Delta_phi_mu_Met > DeltaPhiMuMet
W_df_mu = W_df_mu[W_Mask_1]; m_T_W=m_T_W[W_Mask_1]; m_jj_W=m_jj_W[W_Mask_1]; Delta_eta_W=Delta_eta_W[W_Mask_1]; Mul_eta_W=Mul_eta_W[W_Mask_1]

TTbar_Mask_1=TTbar_df_mu.Delta_phi_mu_Met > DeltaPhiMuMet
TTbar_df_mu = TTbar_df_mu[TTbar_Mask_1]; m_T_ttbar=m_T_ttbar[TTbar_Mask_1]; m_jj_ttbar=m_jj_ttbar[TTbar_Mask_1]; Delta_eta_ttbar=Delta_eta_ttbar[TTbar_Mask_1]; Mul_eta_ttbar=Mul_eta_ttbar[TTbar_Mask_1]

WW_Mask_1=WW_df_mu.Delta_phi_mu_Met > DeltaPhiMuMet
WW_df_mu = WW_df_mu[WW_Mask_1]; m_T_WW=m_T_WW[WW_Mask_1]; m_jj_WW=m_jj_WW[WW_Mask_1]; Delta_eta_WW=Delta_eta_WW[WW_Mask_1]; Mul_eta_WW=Mul_eta_WW[WW_Mask_1]

WZ1_Mask_1=WZ1_df_mu.Delta_phi_mu_Met > DeltaPhiMuMet
WZ1_df_mu = WZ1_df_mu[WZ1_Mask_1]; m_T_WZ1=m_T_WZ1[WZ1_Mask_1]; m_jj_WZ1=m_jj_WZ1[WZ1_Mask_1]; Delta_eta_WZ1=Delta_eta_WZ1[WZ1_Mask_1]; Mul_eta_WZ1=Mul_eta_WZ1[WZ1_Mask_1]

WZ2_Mask_1=WZ2_df_mu.Delta_phi_mu_Met > DeltaPhiMuMet
WZ2_df_mu = WZ2_df_mu[WZ2_Mask_1]; m_T_WZ2=m_T_WZ2[WZ2_Mask_1]; m_jj_WZ2=m_jj_WZ2[WZ2_Mask_1]; Delta_eta_WZ2=Delta_eta_WZ2[WZ2_Mask_1]; Mul_eta_WZ2=Mul_eta_WZ2[WZ2_Mask_1]

S_6=S1_df_mu.shape[0]
W_6=W_df_mu.shape[0]
TTbar_6=TTbar_df_mu.shape[0]
WW_6=WW_df_mu.shape[0]
WZ1_6=WZ1_df_mu.shape[0]
WZ2_6=WZ2_df_mu.shape[0]

print(S_6,W_6,TTbar_6,WW_6,WZ1_6,WZ2_6)
# Out:
# 1532 0 0 0 0 15

# %% [markdown]
# ## Final Significance and efficiencies

# %%
AllCuts=[
    np.array([S_0,W_0,TTbar_0,WW_0,WZ1_0,WZ2_0])*np.array([W_S, W_W, W_TTbar, W_WW, W_WZ1, W_WZ2]),
    np.array([S_1,W_1,TTbar_1,WW_1,WZ1_1,WZ2_1])*np.array([W_S, W_W, W_TTbar, W_WW, W_WZ1, W_WZ2]),
    np.array([S_2,W_2,TTbar_2,WW_2,WZ1_2,WZ2_2])*np.array([W_S, W_W, W_TTbar, W_WW, W_WZ1, W_WZ2]),
    np.array([S_3,W_3,TTbar_3,WW_3,WZ1_3,WZ2_3])*np.array([W_S, W_W, W_TTbar, W_WW, W_WZ1, W_WZ2]),
    np.array([S_4,W_4,TTbar_4,WW_4,WZ1_4,WZ2_4])*np.array([W_S, W_W, W_TTbar, W_WW, W_WZ1, W_WZ2]),
    np.array([S_5,W_5,TTbar_5,WW_5,WZ1_5,WZ2_5])*np.array([W_S, W_W, W_TTbar, W_WW, W_WZ1, W_WZ2]),
    np.array([S_6,W_6,TTbar_6,WW_6,WZ1_6,WZ2_6])*np.array([W_S, W_W, W_TTbar, W_WW, W_WZ1, W_WZ2])
]

# %%
PrintSign(AllCuts)
# Out:
# S/sqrt(S+B)
# Cut 1 2.791555192510688
# Cut 2 3.199128839340699
# Cut 3 4.693585782398666
# Cut 4 8.67516319588875
# Cut 5 19.15971481511215
# Cut 6 19.34563341791231
# Cut 7 21.416303589835252

# %%
EfficiencyTables(AllCuts)
# Out:
# N-1 efficiencies:
# Cut 1 [73.87 45.01 29.77 32.81 31.94 46.69]
# Cut 2 [63.82 19.66 12.51 14.34 14.24 20.26]
# Cut 3 [88.78 20.59 20.31 18.55 21.24 18.92]
# Cut 4 [89.93  4.27  4.82  5.97  8.54  7.82]
# Cut 5 [97.03 77.49 66.23 74.03 71.43 92.86]
# Cut 6 [99.93  0.    0.    0.    0.   57.69]
# Cumulative efficiencies:
# Cut 1 [73.87 45.01 29.77 32.81 31.94 46.69]
# Cut 2 [47.14  8.85  3.72  4.7   4.55  9.46]
# Cut 3 [41.85  1.82  0.76  0.87  0.97  1.79]
# Cut 4 [37.64  0.08  0.04  0.05  0.08  0.14]
# Cut 5 [3.652e+01 6.000e-02 2.000e-02 4.000e-02 6.000e-02 1.300e-01]
# Cut 6 [36.49  0.    0.    0.    0.    0.07]

# %%
plot_ser([m_T_S, m_T_W, m_T_ttbar, m_T_WW, m_T_WZ1, m_T_WZ2], 0, 3000, 30, 
["Signal","W+jets","TTbar","WW","WZ1","WZ2"],["r","k","g","m","b","c",], r"$m_{T}$ [GeV]", size = 14)
# Out:
# /home/jose/.local/lib/python3.9/site-packages/mplhep/utils.py:263: RuntimeWarning: divide by zero encountered in double_scalars
#   self.flat_scale(1 / np.sum(self.values))
# /home/jose/.local/lib/python3.9/site-packages/mplhep/error_estimation.py:38: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(
# /home/jose/.local/lib/python3.9/site-packages/mplhep/utils.py:243: RuntimeWarning: invalid value encountered in multiply
#   self.values *= scale
# /home/jose/.local/lib/python3.9/site-packages/mplhep/utils.py:244: RuntimeWarning: invalid value encountered in multiply
#   self.yerr_lo *= scale
# /home/jose/.local/lib/python3.9/site-packages/mplhep/utils.py:245: RuntimeWarning: invalid value encountered in multiply
#   self.yerr_hi *= scale
# /home/jose/.local/lib/python3.9/site-packages/mplhep/utils.py:263: RuntimeWarning: divide by zero encountered in double_scalars
#   self.flat_scale(1 / np.sum(self.values))
# ...
